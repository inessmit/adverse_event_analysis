# %%
"""Mapping compounds from extracted unbound concentrations, Fu, and Plasma protein binding to ChEMBL approved drugs"""

# %%
import pandas as pd
import numpy as np

# %%
basedir = '/scratch/ias41/ae_code/plasma_concentrations'

# %%
pd.set_option('display.max_colwidth',300)
pd.set_option('display.max_rows',300)

# %%
dataset1 = pd.read_csv(basedir + '/results/interim/PMID22210121_data.txt', sep='\t')
dataset2 = pd.read_csv(basedir + '/results/interim/PMID15637086_data.txt', sep='\t')
dataset3 = pd.read_csv(basedir + '/results/interim/PMID30115648_data.txt', sep='\t')
dataset4 = pd.read_csv(basedir + '/results/interim/PMID12667944_data.txt', sep='\t')
concatenated = pd.concat([dataset1, dataset2, dataset3, dataset4], ignore_index=True, sort=False)

# %%
concatenated.head()
# Out:
#                                    Original drug name Original synonyms  \
# 0  3-Carboxy-4-methyl-5-propyl-2-furan-propionic acid               NaN
# 1                                       Acenocoumarin               NaN
# 2                                       Acetaminophen               NaN
# 3                                          Alprazolam               NaN
# 4                                          Alprenolol               NaN
#
#    PPB lower  PPB upper          PMID  ETCP unbound (nM)  Fu inchi_key SMILES  \
# 0       99.0        NaN  PMID22210121                NaN NaN       NaN    NaN
# 1       99.0        NaN  PMID22210121                NaN NaN       NaN    NaN
# 2        0.0        NaN  PMID22210121                NaN NaN       NaN    NaN
# 3       71.0        NaN  PMID22210121                NaN NaN       NaN    NaN
# 4       85.0        NaN  PMID22210121                NaN NaN       NaN    NaN
#
#    PPB  ETCP unbound (nM) upper
# 0  NaN                      NaN
# 1  NaN                      NaN
# 2  NaN                      NaN
# 3  NaN                      NaN
# 4  NaN                      NaN

# %%
drug_df = concatenated[['Original drug name', 'Original synonyms', 'inchi_key','PMID']].drop_duplicates()
drug_df['Original drug name'] = drug_df['Original drug name'].apply(lambda x: x.upper().strip(' '))
drug_df['Original synonyms'] = drug_df['Original synonyms'].apply(lambda x: str(x).upper().strip(' '))

# %%
drug_df.head()
# Out:
#                                    Original drug name Original synonyms  \
# 0  3-CARBOXY-4-METHYL-5-PROPYL-2-FURAN-PROPIONIC ACID               NAN
# 1                                       ACENOCOUMARIN               NAN
# 2                                       ACETAMINOPHEN               NAN
# 3                                          ALPRAZOLAM               NAN
# 4                                          ALPRENOLOL               NAN
#
#   inchi_key          PMID
# 0       NaN  PMID22210121
# 1       NaN  PMID22210121
# 2       NaN  PMID22210121
# 3       NaN  PMID22210121
# 4       NaN  PMID22210121

# %%
approved = pd.read_csv(basedir + '/data/chembl_approved_drugs.txt', sep='\t')
approved['synonyms'] = approved['synonyms'].apply(lambda x: str(x).upper())

# %%
approved.head()
# Out:
#   chembl_id  molregno pref_name  \
# 0   CHEMBL2        97  PRAZOSIN
# 1   CHEMBL2        97  PRAZOSIN
# 2   CHEMBL2        97  PRAZOSIN
# 3   CHEMBL2        97  PRAZOSIN
# 4   CHEMBL2        97  PRAZOSIN
#
#                                                                      compound_name  \
# 0  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 1  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 2  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 3  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 4  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
#
#   compound_key  synonyms       syn_type           standard_inchi_key  \
# 0            1  PRAZOSIN            ATC  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 1            1  PRAZOSIN            BAN  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 2            1  PRAZOSIN            FDA  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 3            1  PRAZOSIN            INN  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 4            1  CP-12299  RESEARCH_CODE  IENZQIKPVFGBNW-UHFFFAOYSA-N
#
#                                 canonical_smiles  mw_freebase
# 0  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 1  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 2  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 3  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 4  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41

# %%
# Pref_name in approved are not unique - some compounds with different chembl_id have same name
len(approved[['chembl_id', 'pref_name']].drop_duplicates()), len(approved[['pref_name']].drop_duplicates())
# Out:
# (3813, 3741)

# %% [markdown]
# ### Round 1 - mapping on inchi key

# %%
inchi_key_mappings = pd.merge(drug_df, approved[['pref_name', 'chembl_id', 'molregno', 'standard_inchi_key', 'canonical_smiles']].drop_duplicates(), left_on = 'inchi_key', right_on='standard_inchi_key')
inchi_key_mappings = inchi_key_mappings.loc[~inchi_key_mappings['inchi_key'].isnull(),:].drop_duplicates()

# %%
inchi_key_mappings
# Out:
#        Original drug name Original synonyms                    inchi_key  \
# 206388           ABACAVIR               NAN  MCGSCOLBFJQGHM-SCZZXKLOSA-N
# 206389        ACAMPROSATE               NAN  AFCGFAGUEYAMAO-UHFFFAOYSA-N
# 206390         ACEBUTOLOL               NAN  GOEMGAFJFRBGGG-UHFFFAOYSA-N
# 206391      ACETAMINOPHEN               NAN  RZVAJINKPMORJF-UHFFFAOYSA-N
# 206392      ACETAZOLAMIDE               NAN  BZKPWHYZMXOIDC-UHFFFAOYSA-N
# ...                   ...               ...                          ...
# 206968        ZIPRASIDONE               NAN  MVWVFYHBGMAFLY-UHFFFAOYSA-N
# 206969    ZOLEDRONIC ACID               NAN  XRASPMIURGNCCH-UHFFFAOYSA-N
# 206970       ZOLMITRIPTAN               NAN  ULSDMUVEXKOYBU-ZDUSSCGKSA-N
# 206971           ZOLPIDEM               NAN  ZAFYATHCZYHLPB-UHFFFAOYSA-N
# 206972          ZOPICLONE               NAN  GBBSUAFBMRNDJC-UHFFFAOYSA-N
#
#                 PMID        pref_name      chembl_id  molregno  \
# 206388  PMID30115648         ABACAVIR     CHEMBL1380    321707
# 206389  PMID30115648      ACAMPROSATE  CHEMBL1201293    675244
# 206390  PMID30115648       ACEBUTOLOL      CHEMBL642     27347
# 206391  PMID30115648    ACETAMINOPHEN      CHEMBL112     16450
# 206392  PMID30115648    ACETAZOLAMIDE       CHEMBL20      1125
# ...              ...              ...            ...       ...
# 206968  PMID30115648      ZIPRASIDONE      CHEMBL708     33664
# 206969  PMID30115648  ZOLEDRONIC ACID      CHEMBL924     83838
# 206970  PMID30115648     ZOLMITRIPTAN     CHEMBL1185    196215
# 206971  PMID30115648         ZOLPIDEM      CHEMBL911     80965
# 206972  PMID30115648        ZOPICLONE   CHEMBL135400    224263
#
#                  standard_inchi_key  \
# 206388  MCGSCOLBFJQGHM-SCZZXKLOSA-N
# 206389  AFCGFAGUEYAMAO-UHFFFAOYSA-N
# 206390  GOEMGAFJFRBGGG-UHFFFAOYSA-N
# 206391  RZVAJINKPMORJF-UHFFFAOYSA-N
# 206392  BZKPWHYZMXOIDC-UHFFFAOYSA-N
# ...                             ...
# 206968  MVWVFYHBGMAFLY-UHFFFAOYSA-N
# 206969  XRASPMIURGNCCH-UHFFFAOYSA-N
# 206970  ULSDMUVEXKOYBU-ZDUSSCGKSA-N
# 206971  ZAFYATHCZYHLPB-UHFFFAOYSA-N
# 206972  GBBSUAFBMRNDJC-UHFFFAOYSA-N
#
#                                         canonical_smiles
# 206388     Nc1nc(NC2CC2)c3ncn([C@@H]4C[C@H](CO)C=C4)c3n1
# 206389                              CC(=O)NCCCS(=O)(=O)O
# 206390          CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(c1)C(=O)C
# 206391                                CC(=O)Nc1ccc(O)cc1
# 206392                        CC(=O)Nc1nnc(s1)S(=O)(=O)N
# ...                                                  ...
# 206968      Clc1cc2NC(=O)Cc2cc1CCN3CCN(CC3)c4nsc5ccccc45
# 206969                  OC(Cn1ccnc1)(P(=O)(O)O)P(=O)(O)O
# 206970         CN(C)CCc1c[nH]c2ccc(C[C@H]3COC(=O)N3)cc12
# 206971          CN(C)C(=O)Cc1c(nc2ccc(C)cn12)c3ccc(C)cc3
# 206972  CN1CCN(CC1)C(=O)OC2N(C(=O)c3nccnc23)c4ccc(Cl)cn4
#
# [585 rows x 9 columns]

# %% [markdown]
# ### Round 2 - mapping on pref_name

# %%
pref_name_mappings = pd.merge(drug_df.loc[~drug_df['inchi_key'].isin(list(inchi_key_mappings['inchi_key'])),:], approved[['pref_name', 'chembl_id','molregno', 'standard_inchi_key', 'canonical_smiles']].drop_duplicates(), left_on = 'Original drug name', right_on='pref_name').drop_duplicates()
pref_name_mappings
# Out:
#     Original drug name Original synonyms inchi_key          PMID  \
# 0        ACETAMINOPHEN               NAN       NaN  PMID22210121
# 1           ALPRAZOLAM               NAN       NaN  PMID22210121
# 2            AMILORIDE               NAN       NaN  PMID22210121
# 3           AMIODARONE               NAN       NaN  PMID22210121
# 4           AMIODARONE               NAN       NaN  PMID15637086
# ..                 ...               ...       ...           ...
# 430        DOXORUBICIN               NAN       NaN  PMID12667944
# 431          ENCAINIDE               NAN       NaN  PMID12667944
# 432        HYDROXYZINE               NAN       NaN  PMID12667944
# 433         PYRILAMINE               NAN       NaN  PMID12667944
# 434         QUETIAPINE               NAN       NaN  PMID12667944
#
#          pref_name     chembl_id  molregno           standard_inchi_key  \
# 0    ACETAMINOPHEN     CHEMBL112     16450  RZVAJINKPMORJF-UHFFFAOYSA-N
# 1       ALPRAZOLAM     CHEMBL661     27648  VREFGVBLTWBCJP-UHFFFAOYSA-N
# 2        AMILORIDE     CHEMBL945     89526  XSDQTOBWRPYKKA-UHFFFAOYSA-N
# 3       AMIODARONE     CHEMBL633     27185  IYIKLHRQXLHMJQ-UHFFFAOYSA-N
# 4       AMIODARONE     CHEMBL633     27185  IYIKLHRQXLHMJQ-UHFFFAOYSA-N
# ..             ...           ...       ...                          ...
# 430    DOXORUBICIN   CHEMBL53463     78759  AOJJSUZBOXZQNB-TZSSRYMLSA-N
# 431      ENCAINIDE  CHEMBL315838    139046  PJWPNDMDCLXCOM-UHFFFAOYSA-N
# 432    HYDROXYZINE     CHEMBL896     77459  ZQDWXGKKHFNSQK-UHFFFAOYSA-N
# 433     PYRILAMINE     CHEMBL511     10661  YECBIJXISLIIDS-UHFFFAOYSA-N
# 434     QUETIAPINE     CHEMBL716     34234  URKOMYMAXPYINW-UHFFFAOYSA-N
#
#                                                                                       canonical_smiles
# 0                                                                                   CC(=O)Nc1ccc(O)cc1
# 1                                                                 Cc1nnc2CN=C(c3ccccc3)c4cc(Cl)ccc4n12
# 2                                                                         NC(=N)NC(=O)c1nc(Cl)c(N)nc1N
# 3                                                     CCCCc1oc2ccccc2c1C(=O)c3cc(I)c(OCCN(CC)CC)c(I)c3
# 4                                                     CCCCc1oc2ccccc2c1C(=O)c3cc(I)c(OCCN(CC)CC)c(I)c3
# ..                                                                                                 ...
# 430  COc1cccc2C(=O)c3c(O)c4C[C@](O)(C[C@H](O[C@H]5C[C@H](N)[C@H](O)[C@H](C)O5)c4c(O)c3C(=O)c12)C(=O)CO
# 431                                                              COc1ccc(cc1)C(=O)Nc2ccccc2CCC3CCCCN3C
# 432                                                            OCCOCCN1CCN(CC1)C(c2ccccc2)c3ccc(Cl)cc3
# 433                                                                    COc1ccc(CN(CCN(C)C)c2ccccn2)cc1
# 434                                                             OCCOCCN1CCN(CC1)C2=Nc3ccccc3Sc4ccccc24
#
# [435 rows x 9 columns]

# %%
all_mappings = pd.concat([inchi_key_mappings, pref_name_mappings],sort=False,ignore_index=True).drop_duplicates()

# %%
all_mappings.sort_values(by='pref_name')
# Out:
#     Original drug name Original synonyms                    inchi_key  \
# 0             ABACAVIR               NAN  MCGSCOLBFJQGHM-SCZZXKLOSA-N
# 1          ACAMPROSATE               NAN  AFCGFAGUEYAMAO-UHFFFAOYSA-N
# 2           ACEBUTOLOL               NAN  GOEMGAFJFRBGGG-UHFFFAOYSA-N
# 892      ACENOCOUMAROL               NAN  VABCILAOYCMVPS-OAHLLOKOSA-N
# 3        ACETAMINOPHEN               NAN  RZVAJINKPMORJF-UHFFFAOYSA-N
# ..                 ...               ...                          ...
# 581    ZOLEDRONIC ACID               NAN  XRASPMIURGNCCH-UHFFFAOYSA-N
# 582       ZOLMITRIPTAN               NAN  ULSDMUVEXKOYBU-ZDUSSCGKSA-N
# 583           ZOLPIDEM               NAN  ZAFYATHCZYHLPB-UHFFFAOYSA-N
# 825          ZOMEPIRAC               NAN                          NaN
# 584          ZOPICLONE               NAN  GBBSUAFBMRNDJC-UHFFFAOYSA-N
#
#              PMID        pref_name      chembl_id  molregno  \
# 0    PMID30115648         ABACAVIR     CHEMBL1380    321707
# 1    PMID30115648      ACAMPROSATE  CHEMBL1201293    675244
# 2    PMID30115648       ACEBUTOLOL      CHEMBL642     27347
# 892  PMID30115648    ACENOCOUMAROL   CHEMBL397420    394206
# 3    PMID30115648    ACETAMINOPHEN      CHEMBL112     16450
# ..            ...              ...            ...       ...
# 581  PMID30115648  ZOLEDRONIC ACID      CHEMBL924     83838
# 582  PMID30115648     ZOLMITRIPTAN     CHEMBL1185    196215
# 583  PMID30115648         ZOLPIDEM      CHEMBL911     80965
# 825  PMID22210121        ZOMEPIRAC    CHEMBL19490     23001
# 584  PMID30115648        ZOPICLONE   CHEMBL135400    224263
#
#               standard_inchi_key  \
# 0    MCGSCOLBFJQGHM-SCZZXKLOSA-N
# 1    AFCGFAGUEYAMAO-UHFFFAOYSA-N
# 2    GOEMGAFJFRBGGG-UHFFFAOYSA-N
# 892  VABCILAOYCMVPS-UHFFFAOYSA-N
# 3    RZVAJINKPMORJF-UHFFFAOYSA-N
# ..                           ...
# 581  XRASPMIURGNCCH-UHFFFAOYSA-N
# 582  ULSDMUVEXKOYBU-ZDUSSCGKSA-N
# 583  ZAFYATHCZYHLPB-UHFFFAOYSA-N
# 825  ZXVNMYWKKDOREA-UHFFFAOYSA-N
# 584  GBBSUAFBMRNDJC-UHFFFAOYSA-N
#
#                                          canonical_smiles
# 0           Nc1nc(NC2CC2)c3ncn([C@@H]4C[C@H](CO)C=C4)c3n1
# 1                                    CC(=O)NCCCS(=O)(=O)O
# 2                CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(c1)C(=O)C
# 892  CC(=O)CC(C1=C(O)c2ccccc2OC1=O)c3ccc(cc3)[N+](=O)[O-]
# 3                                      CC(=O)Nc1ccc(O)cc1
# ..                                                    ...
# 581                      OC(Cn1ccnc1)(P(=O)(O)O)P(=O)(O)O
# 582             CN(C)CCc1c[nH]c2ccc(C[C@H]3COC(=O)N3)cc12
# 583              CN(C)C(=O)Cc1c(nc2ccc(C)cn12)c3ccc(C)cc3
# 825                 Cc1cc(CC(=O)O)n(C)c1C(=O)c2ccc(Cl)cc2
# 584      CN1CCN(CC1)C(=O)OC2N(C(=O)c3nccnc23)c4ccc(Cl)cn4
#
# [1020 rows x 9 columns]

# %% [markdown]
# ### Round 3 - mapping of source synonym to chembl pref_name

# %%
unmapped = drug_df.loc[(~drug_df['Original drug name'].isin(list(all_mappings['Original drug name'])))&(~drug_df['inchi_key'].isin(list(all_mappings['standard_inchi_key']))),:]

# %%
len(unmapped)
# Out:
# 216

# %%
synonym_pref_name_mappings_initial = pd.merge(drug_df, approved[['pref_name', 'chembl_id','molregno', 'standard_inchi_key','canonical_smiles']].drop_duplicates(), left_on='Original synonyms', right_on='pref_name').drop_duplicates().sort_values(by='pref_name')

# %%
synonym_pref_name_mappings_initial
# Out:
# Empty DataFrame
# Columns: [Original drug name, Original synonyms, inchi_key, PMID, pref_name, chembl_id, molregno, standard_inchi_key, canonical_smiles]
# Index: []

# %% [markdown]
# # Round 4

# %%
# Original drug name to ChEMBL synonyms
substance_synonyms_mappings = pd.merge(unmapped, approved, left_on='Original drug name', right_on='synonyms')[['pref_name','Original drug name','syn_type','chembl_id','molregno', 'standard_inchi_key','canonical_smiles']].drop_duplicates()

# %%
# Inspect manually and decide which ones to drop
substance_synonyms_mappings.sort_values(by='Original drug name')
# Out:
#                         pref_name Original drug name syn_type      chembl_id  \
# 0           CANDESARTAN CILEXETIL        CANDESARTAN      BAN     CHEMBL1014
# 11          FLUDARABINE PHOSPHATE        FLUDARABINE      ATC  CHEMBL1096882
# 12          FLUDARABINE PHOSPHATE        FLUDARABINE      INN  CHEMBL1096882
# 15              GANIRELIX ACETATE          GANIRELIX      ATC     CHEMBL1251
# 16              GANIRELIX ACETATE          GANIRELIX      BAN     CHEMBL1251
# 17              GANIRELIX ACETATE          GANIRELIX      BNF     CHEMBL1251
# 18              GANIRELIX ACETATE          GANIRELIX      INN     CHEMBL1251
# 23  TENOFOVIR DISOPROXIL FUMARATE          TENOFOVIR      BAN     CHEMBL1486
# 24  TENOFOVIR DISOPROXIL FUMARATE          TENOFOVIR      INN     CHEMBL1486
# 35                      ZIMELDINE         ZIMELIDINE    OTHER    CHEMBL37744
#
#     molregno           standard_inchi_key  \
# 0     116349  GHOSNRCGJFBJIB-UHFFFAOYSA-N
# 11    624161  GIUYCYHIANZCFB-FJFJXFQQSA-N
# 12    624161  GIUYCYHIANZCFB-FJFJXFQQSA-N
# 15    236376  GJNXBNATEDXMAK-PFLSVRRQSA-N
# 16    236376  GJNXBNATEDXMAK-PFLSVRRQSA-N
# 17    236376  GJNXBNATEDXMAK-PFLSVRRQSA-N
# 18    236376  GJNXBNATEDXMAK-PFLSVRRQSA-N
# 23    417163  VCMJCVGFSROFHV-WZGZYPNHSA-N
# 24    417163  VCMJCVGFSROFHV-WZGZYPNHSA-N
# 35     54070  OYPPVKRFBIWMSX-SXGWCWSVSA-N
#
#                                                                                                                                                                                                                                          canonical_smiles
# 0                                                                                                                                                                                CCOc1nc2cccc(C(=O)OC(C)OC(=O)OC3CCCCC3)c2n1Cc4ccc(cc4)c5ccccc5c6nn[nH]n6
# 11                                                                                                                                                                                           Nc1nc(F)nc2c1ncn2[C@@H]3O[C@H](COP(=O)(O)O)[C@@H](O)[C@@H]3O
# 12                                                                                                                                                                                           Nc1nc(F)nc2c1ncn2[C@@H]3O[C@H](COP(=O)(O)O)[C@@H](O)[C@@H]3O
# 15  CCN\\C(=N/CC)\\NCCCC[C@@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@H](CO)NC(=O)[C@@H](Cc2cccnc2)NC(=O)[C@@H](Cc3ccc(Cl)cc3)NC(=O)[C@@H](Cc4ccc5ccccc5c4)NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCCN\\C(=N\\CC)\\NCC)C(=O)N6CCC[C@H]6C(=O)N[C@H](C)C(=O)N
# 16  CCN\\C(=N/CC)\\NCCCC[C@@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@H](CO)NC(=O)[C@@H](Cc2cccnc2)NC(=O)[C@@H](Cc3ccc(Cl)cc3)NC(=O)[C@@H](Cc4ccc5ccccc5c4)NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCCN\\C(=N\\CC)\\NCC)C(=O)N6CCC[C@H]6C(=O)N[C@H](C)C(=O)N
# 17  CCN\\C(=N/CC)\\NCCCC[C@@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@H](CO)NC(=O)[C@@H](Cc2cccnc2)NC(=O)[C@@H](Cc3ccc(Cl)cc3)NC(=O)[C@@H](Cc4ccc5ccccc5c4)NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCCN\\C(=N\\CC)\\NCC)C(=O)N6CCC[C@H]6C(=O)N[C@H](C)C(=O)N
# 18  CCN\\C(=N/CC)\\NCCCC[C@@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@H](CO)NC(=O)[C@@H](Cc2cccnc2)NC(=O)[C@@H](Cc3ccc(Cl)cc3)NC(=O)[C@@H](Cc4ccc5ccccc5c4)NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCCN\\C(=N\\CC)\\NCC)C(=O)N6CCC[C@H]6C(=O)N[C@H](C)C(=O)N
# 23                                                                                                                                                                     CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc12)OCOC(=O)OC(C)C.OC(=O)\\C=C\\C(=O)O
# 24                                                                                                                                                                     CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc12)OCOC(=O)OC(C)C.OC(=O)\\C=C\\C(=O)O
# 35                                                                                                                                                                                                                   CN(C)C\\C=C(\\c1ccc(Br)cc1)/c2cccnc2

# %%
# accept all but tenofovir and candesartan - these are phase 3
to_drop = ['CHEMBL1014', 'CHEMBL1486']
substance_synonyms_mappings_to_add = substance_synonyms_mappings.loc[~substance_synonyms_mappings['chembl_id'].isin(to_drop),all_mappings.columns].drop_duplicates()
# Out:
# /scratch/ias41/envs/release/lib/python3.6/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
substance_synonyms_mappings_to_add
# Out:
#    Original drug name  Original synonyms  inchi_key  PMID  \
# 11        FLUDARABINE                NaN        NaN   NaN
# 15          GANIRELIX                NaN        NaN   NaN
# 35         ZIMELIDINE                NaN        NaN   NaN
#
#                 pref_name      chembl_id  molregno  \
# 11  FLUDARABINE PHOSPHATE  CHEMBL1096882    624161
# 15      GANIRELIX ACETATE     CHEMBL1251    236376
# 35              ZIMELDINE    CHEMBL37744     54070
#
#              standard_inchi_key  \
# 11  GIUYCYHIANZCFB-FJFJXFQQSA-N
# 15  GJNXBNATEDXMAK-PFLSVRRQSA-N
# 35  OYPPVKRFBIWMSX-SXGWCWSVSA-N
#
#                                                                                                                                                                                                                                          canonical_smiles
# 11                                                                                                                                                                                           Nc1nc(F)nc2c1ncn2[C@@H]3O[C@H](COP(=O)(O)O)[C@@H](O)[C@@H]3O
# 15  CCN\\C(=N/CC)\\NCCCC[C@@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@H](CO)NC(=O)[C@@H](Cc2cccnc2)NC(=O)[C@@H](Cc3ccc(Cl)cc3)NC(=O)[C@@H](Cc4ccc5ccccc5c4)NC(=O)C)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCCN\\C(=N\\CC)\\NCC)C(=O)N6CCC[C@H]6C(=O)N[C@H](C)C(=O)N
# 35                                                                                                                                                                                                                   CN(C)C\\C=C(\\c1ccc(Br)cc1)/c2cccnc2

# %%
len(all_mappings)
# Out:
# 1020

# %%
all_mappings = pd.concat([all_mappings, substance_synonyms_mappings_to_add], sort=False,ignore_index=True).drop_duplicates()

# %%
len(all_mappings)
# Out:
# 1023

# %%
all_mappings.head()
# Out:
#   Original drug name Original synonyms                    inchi_key  \
# 0           ABACAVIR               NAN  MCGSCOLBFJQGHM-SCZZXKLOSA-N
# 1        ACAMPROSATE               NAN  AFCGFAGUEYAMAO-UHFFFAOYSA-N
# 2         ACEBUTOLOL               NAN  GOEMGAFJFRBGGG-UHFFFAOYSA-N
# 3      ACETAMINOPHEN               NAN  RZVAJINKPMORJF-UHFFFAOYSA-N
# 4      ACETAZOLAMIDE               NAN  BZKPWHYZMXOIDC-UHFFFAOYSA-N
#
#            PMID      pref_name      chembl_id  molregno  \
# 0  PMID30115648       ABACAVIR     CHEMBL1380    321707
# 1  PMID30115648    ACAMPROSATE  CHEMBL1201293    675244
# 2  PMID30115648     ACEBUTOLOL      CHEMBL642     27347
# 3  PMID30115648  ACETAMINOPHEN      CHEMBL112     16450
# 4  PMID30115648  ACETAZOLAMIDE       CHEMBL20      1125
#
#             standard_inchi_key                               canonical_smiles
# 0  MCGSCOLBFJQGHM-SCZZXKLOSA-N  Nc1nc(NC2CC2)c3ncn([C@@H]4C[C@H](CO)C=C4)c3n1
# 1  AFCGFAGUEYAMAO-UHFFFAOYSA-N                           CC(=O)NCCCS(=O)(=O)O
# 2  GOEMGAFJFRBGGG-UHFFFAOYSA-N       CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(c1)C(=O)C
# 3  RZVAJINKPMORJF-UHFFFAOYSA-N                             CC(=O)Nc1ccc(O)cc1
# 4  BZKPWHYZMXOIDC-UHFFFAOYSA-N                     CC(=O)Nc1nnc(s1)S(=O)(=O)N

# %% [markdown]
# # Round 5

# %%
unmapped_2 = drug_df.loc[(~drug_df['Original drug name'].isin(list(all_mappings['Original drug name'])))&(~drug_df['inchi_key'].isin(list(all_mappings['standard_inchi_key']))),:]

# %%
len(unmapped_2)
# Out:
# 213

# %%
unmapped_2.head()
# Out:
#               Original drug name     Original synonyms  \
# 275            16-ACETYL GITOXIN                   NAN
# 276  5-HYDROXYMETHYL TOLTERODINE                   NAN
# 280                   ACECAINIDE  N-ACETYLPROCAINAMIDE
# 287                   ACTISOMIDE                   NAN
# 289                     ADEFOVIR                   NAN
#
#                        inchi_key          PMID
# 275  NEBPBFLVSYFRQE-ZYMOIYFGSA-N  PMID30115648
# 276  DUXZAXCGJSBGDW-HXUWFJFHSA-N  PMID30115648
# 280  KEECCEWTUVWFCV-UHFFFAOYSA-N  PMID30115648
# 287  QAHRRCMLXFLZTF-FYYLOGMGSA-N  PMID30115648
# 289  SUPKOOSCJHTBAH-UHFFFAOYSA-N  PMID30115648

# %%
# Substance to compound name
# Original drug name to ChEMBL synonyms
round5_mappings = pd.merge(unmapped_2, approved, left_on='Original drug name', right_on='compound_name')[['pref_name','Original drug name','chembl_id','molregno',]].drop_duplicates()

# %%
round5_mappings
# Out:
# Empty DataFrame
# Columns: [pref_name, Original drug name, chembl_id, molregno]
# Index: []

# %% [markdown]
# # Round 6
# Synonyms to synonyms

# %%
# Synonyms to synonyms
syn_to_syn_mappings = pd.merge(unmapped_2.loc[~unmapped_2['Original synonyms'].isnull(),:], approved, left_on='Original synonyms',right_on='synonyms')[['Original drug name','pref_name','Original synonyms','syn_type','chembl_id','molregno', 'standard_inchi_key','canonical_smiles']].drop_duplicates()
syn_to_syn_mappings = syn_to_syn_mappings.loc[syn_to_syn_mappings['Original synonyms']!='NAN',:]

# %%
syn_to_syn_mappings
# Out:
# Empty DataFrame
# Columns: [Original drug name, pref_name, Original synonyms, syn_type, chembl_id, molregno, standard_inchi_key, canonical_smiles]
# Index: []

# %%
len(all_mappings)
# Out:
# 1023

# %%
all_mappings.loc[all_mappings['Original drug name']=='DOXYCYCLINE']
# Out:
#     Original drug name Original synonyms                    inchi_key  \
# 190        DOXYCYCLINE               NAN  JBIWCJUYHHGXTC-AKNGSSGZSA-N
# 658        DOXYCYCLINE               NAN                          NaN
# 659        DOXYCYCLINE               NAN                          NaN
#
#              PMID    pref_name      chembl_id  molregno  \
# 190  PMID30115648  DOXYCYCLINE     CHEMBL1433    371546
# 658  PMID22210121  DOXYCYCLINE     CHEMBL1433    371546
# 659  PMID22210121  DOXYCYCLINE  CHEMBL1200699    674650
#
#               standard_inchi_key  \
# 190  JBIWCJUYHHGXTC-AKNGSSGZSA-N
# 658  JBIWCJUYHHGXTC-AKNGSSGZSA-N
# 659  XQTWDDCIUJNLTR-CVHRZJFOSA-N
#
#                                                                                    canonical_smiles
# 190    C[C@@H]1[C@H]2[C@H](O)[C@H]3[C@H](N(C)C)C(=C(C(=O)N)C(=O)[C@@]3(O)C(=C2C(=O)c4c(O)cccc14)O)O
# 658    C[C@@H]1[C@H]2[C@H](O)[C@H]3[C@H](N(C)C)C(=C(C(=O)N)C(=O)[C@@]3(O)C(=C2C(=O)c4c(O)cccc14)O)O
# 659  O.C[C@@H]1[C@H]2[C@H](O)[C@H]3[C@H](N(C)C)C(=C(C(=O)N)C(=O)[C@@]3(O)C(=C2C(=O)c4c(O)cccc14)O)O

# %%
# Checking that all 'substance' only have one mapping to chembl_id
for name in list(set(all_mappings['Original drug name'])):
    subset_df = all_mappings.loc[all_mappings['Original drug name']==name,'molregno'].drop_duplicates()
    if len(subset_df)>1:
        print(name)
# Out:
# DOXYCYCLINE
# LORACARBEF
# CISAPRIDE
# CEFACLOR
# TACROLIMUS
# OXYPHENBUTAZONE
# CEPHALEXIN
# PINACIDIL
# CEFPROZIL
# SAXAGLIPTIN
# INDOCYANINE GREEN

# %%
# Drop non-parents
to_be_dropped = ['CHEMBL1200788', 'CHEMBL1200544', 'CHEMBL1646', 'CHEMBL3184906', 'CHEMBL3989887', 'CHEMBL2103745', 'CHEMBL1201018', 'CHEMBL3989676', 'CHEMBL1200610', 'CHEMBL1200338', 'CHEMBL1200699']

# %%
all_mappings = all_mappings.loc[~all_mappings['chembl_id'].isin(to_be_dropped),:]

# %%
len(all_mappings)
# Out:
# 1009

# %%
# Checking that all 'substance' only have one mapping to chembl_id
for name in list(set(all_mappings['Original drug name'])):
    subset_df = all_mappings.loc[all_mappings['Original drug name']==name,'molregno'].drop_duplicates()
    if len(subset_df)>1:
        print(name)

# %% [markdown]
# # See currently unmapped

# %%
unmapped_3 = drug_df.loc[(~drug_df['Original drug name'].isin(list(all_mappings['Original drug name'])))&(~drug_df['inchi_key'].isin(list(all_mappings['standard_inchi_key']))),:]

# %%
unmapped_3.head()
# Out:
#               Original drug name     Original synonyms  \
# 275            16-ACETYL GITOXIN                   NAN
# 276  5-HYDROXYMETHYL TOLTERODINE                   NAN
# 280                   ACECAINIDE  N-ACETYLPROCAINAMIDE
# 287                   ACTISOMIDE                   NAN
# 289                     ADEFOVIR                   NAN
#
#                        inchi_key          PMID
# 275  NEBPBFLVSYFRQE-ZYMOIYFGSA-N  PMID30115648
# 276  DUXZAXCGJSBGDW-HXUWFJFHSA-N  PMID30115648
# 280  KEECCEWTUVWFCV-UHFFFAOYSA-N  PMID30115648
# 287  QAHRRCMLXFLZTF-FYYLOGMGSA-N  PMID30115648
# 289  SUPKOOSCJHTBAH-UHFFFAOYSA-N  PMID30115648

# %%
unmapped_3['short substance'] = unmapped_3['Original drug name'].apply(lambda x: x.rstrip('E'))
# Out:
# /scratch/ias41/envs/release/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
unmapped_3.head()
# Out:
#               Original drug name     Original synonyms  \
# 275            16-ACETYL GITOXIN                   NAN
# 276  5-HYDROXYMETHYL TOLTERODINE                   NAN
# 280                   ACECAINIDE  N-ACETYLPROCAINAMIDE
# 287                   ACTISOMIDE                   NAN
# 289                     ADEFOVIR                   NAN
#
#                        inchi_key          PMID             short substance
# 275  NEBPBFLVSYFRQE-ZYMOIYFGSA-N  PMID30115648           16-ACETYL GITOXIN
# 276  DUXZAXCGJSBGDW-HXUWFJFHSA-N  PMID30115648  5-HYDROXYMETHYL TOLTERODIN
# 280  KEECCEWTUVWFCV-UHFFFAOYSA-N  PMID30115648                   ACECAINID
# 287  QAHRRCMLXFLZTF-FYYLOGMGSA-N  PMID30115648                   ACTISOMID
# 289  SUPKOOSCJHTBAH-UHFFFAOYSA-N  PMID30115648                    ADEFOVIR

# %% [markdown]
# ## Attach mappings after considering trailing 'e'

# %%
# Noticed some names had an 'e' on the end that prevented synonym mapping
my_columns = [i for i in all_mappings.columns]
short_names = pd.merge(unmapped_3, approved, left_on='short substance', right_on='pref_name')[my_columns].drop_duplicates()
short_names
# Out:
# Empty DataFrame
# Columns: [Original drug name, Original synonyms, inchi_key, PMID, pref_name, chembl_id, molregno, standard_inchi_key, canonical_smiles]
# Index: []

# %%
len(set(drug_df['Original drug name'])), len(set(all_mappings['Original drug name'])), len(set(all_mappings['molregno']))
# Out:
# (1027, 778, 773)

# %%
all_mappings.head()
# Out:
#   Original drug name Original synonyms                    inchi_key  \
# 0           ABACAVIR               NAN  MCGSCOLBFJQGHM-SCZZXKLOSA-N
# 1        ACAMPROSATE               NAN  AFCGFAGUEYAMAO-UHFFFAOYSA-N
# 2         ACEBUTOLOL               NAN  GOEMGAFJFRBGGG-UHFFFAOYSA-N
# 3      ACETAMINOPHEN               NAN  RZVAJINKPMORJF-UHFFFAOYSA-N
# 4      ACETAZOLAMIDE               NAN  BZKPWHYZMXOIDC-UHFFFAOYSA-N
#
#            PMID      pref_name      chembl_id  molregno  \
# 0  PMID30115648       ABACAVIR     CHEMBL1380    321707
# 1  PMID30115648    ACAMPROSATE  CHEMBL1201293    675244
# 2  PMID30115648     ACEBUTOLOL      CHEMBL642     27347
# 3  PMID30115648  ACETAMINOPHEN      CHEMBL112     16450
# 4  PMID30115648  ACETAZOLAMIDE       CHEMBL20      1125
#
#             standard_inchi_key                               canonical_smiles
# 0  MCGSCOLBFJQGHM-SCZZXKLOSA-N  Nc1nc(NC2CC2)c3ncn([C@@H]4C[C@H](CO)C=C4)c3n1
# 1  AFCGFAGUEYAMAO-UHFFFAOYSA-N                           CC(=O)NCCCS(=O)(=O)O
# 2  GOEMGAFJFRBGGG-UHFFFAOYSA-N       CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(c1)C(=O)C
# 3  RZVAJINKPMORJF-UHFFFAOYSA-N                             CC(=O)Nc1ccc(O)cc1
# 4  BZKPWHYZMXOIDC-UHFFFAOYSA-N                     CC(=O)Nc1nnc(s1)S(=O)(=O)N

# %%
# Need to match back to original datasets

# %%
ds1_mappings = all_mappings.loc[all_mappings['PMID']=='PMID22210121',:][['Original drug name', 'chembl_id', 'molregno']]
dataset1['Original drug name'] = dataset1['Original drug name'].apply(lambda x: x.upper().strip(' '))
ds1_result = ds1_mappings.merge(dataset1, on='Original drug name', how='inner')
ds1_result.to_csv(basedir + '/results/interim/PMID22210121_mapped_data.txt', sep='\t', index=False)

# %%
ds2_mappings = all_mappings.loc[all_mappings['PMID']=='PMID15637086',:][['Original drug name', 'chembl_id', 'molregno']]
dataset2['Original drug name'] = dataset2['Original drug name'].apply(lambda x: x.upper().strip(' '))
ds2_result = ds2_mappings.merge(dataset2, on='Original drug name', how='inner')
ds2_result.to_csv(basedir + '/results/interim/PMID15637086_mapped_data.txt', sep='\t', index=False)

# %%
ds3_mappings = all_mappings.loc[all_mappings['PMID']=='PMID30115648',:][['Original drug name', 'chembl_id', 'molregno']]
dataset3['Original drug name'] = dataset3['Original drug name'].apply(lambda x: x.upper().strip(' '))
ds3_result = ds3_mappings.merge(dataset3, on='Original drug name', how='inner')
ds3_result.to_csv(basedir + '/results/interim/PMID30115648_mapped_data.txt', sep='\t', index=False)

# %%
ds4_mappings = all_mappings.loc[all_mappings['PMID']=='PMID12667944',:][['Original drug name', 'chembl_id', 'molregno']]
dataset4['Original drug name'] = dataset4['Original drug name'].apply(lambda x: x.upper().strip(' '))
ds4_result = ds4_mappings.merge(dataset4, on='Original drug name', how='inner')
ds4_result.to_csv(basedir + '/results/interim/PMID12667944_mapped_data.txt', sep='\t', index=False)
