# %%
"""Mapping drugs from Schulz ea publication with plasma concentrations to ChEMBL approved drugs"""
# Out:
# 'Mapping drugs from Schulz ea publication with plasma concentrations to ChEMBL approved drugs'

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_colwidth',300)
pd.set_option('display.max_rows',300)

# %%
basedir = '/scratch/ias41/ae_code/plasma_concentrations'

# %%
plasma = pd.read_csv(basedir + '/data/Schulz_ea_upper_values_formatted.txt', sep='\t')
plasma['Substance'] = plasma['Substance'].apply(lambda x: x.rstrip(' ').upper())
plasma['Synonym'] = plasma['Synonym'].apply(lambda x: x.upper() if type(x)==str else np.NaN)

# %%
plasma.head(20)
# Out:
#                Substance      Salts Synonym  \
# 0               ABACAVIR        NaN     NaN
# 1            ACAMPROSATE        NaN     NaN
# 2             ACEBUTOLOL        NaN     NaN
# 3          ACENOCOUMAROL        NaN     NaN
# 4           ACETALDEHYDE        NaN     NaN
# 5          ACETAZOLAMIDE        NaN     NaN
# 6          ACETOHEXAMIDE        NaN     NaN
# 7                ACETONE        NaN     NaN
# 8          ACETYLDIGOXIN        NaN     NaN
# 9   ACETYLSALICYLIC ACID        NaN     NaN
# 10             ACITRETIN        NaN     NaN
# 11           ACRIVASTINE        NaN     NaN
# 12             ACYCLOVIR        NaN     NaN
# 13            ADALIMUMAB        NaN     NaN
# 14            ADIPIODONE  meglumine     NaN
# 15           AGOMELATINE        NaN     NaN
# 16              AJMALINE        NaN     NaN
# 17           ALBENDAZOLE        NaN     NaN
# 18            ALCURONIUM        NaN     NaN
# 19                ALDRIN        NaN     NaN
#
#     Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit
# 0                                                               3.9000  NaN
# 1                                                               0.7000  NaN
# 2                                                               2.0000  NaN
# 3                                                               0.5000  NaN
# 4                                                              30.0000  NaN
# 5                                                              20.0000  NaN
# 6                                                              70.0000  NaN
# 7                                                              20.0000  NaN
# 8                                                               0.0008  NaN
# 9                                                             200.0000  NaN
# 10                                                              0.0500  NaN
# 11                                                              0.0700  NaN
# 12                                                             15.0000  NaN
# 13                                                              9.0000  NaN
# 14                                                           1200.0000  NaN
# 15                                                              0.3000  NaN
# 16                                                              2.2100  NaN
# 17                                                              1.5000  NaN
# 18                                                              3.0000  NaN
# 19                                                              0.0015  NaN

# %%
approved = pd.read_csv(basedir + '/data/chembl_approved_drugs.txt', sep='\t')
approved['synonyms'] = approved['synonyms'].apply(lambda x: str(x).upper())

# %%
approved.head()
# Out:
#   chembl_id  molregno pref_name  \
# 0   CHEMBL2        97  PRAZOSIN
# 1   CHEMBL2        97  PRAZOSIN
# 2   CHEMBL2        97  PRAZOSIN
# 3   CHEMBL2        97  PRAZOSIN
# 4   CHEMBL2        97  PRAZOSIN
#
#                                                                      compound_name  \
# 0  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 1  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 2  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 3  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
# 4  [4-(4-Amino-6,7-dimethoxy-quinazolin-2-yl)-piperazin-1-yl]-furan-2-yl-methanone
#
#   compound_key  synonyms       syn_type           standard_inchi_key  \
# 0            1  PRAZOSIN            ATC  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 1            1  PRAZOSIN            BAN  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 2            1  PRAZOSIN            FDA  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 3            1  PRAZOSIN            INN  IENZQIKPVFGBNW-UHFFFAOYSA-N
# 4            1  CP-12299  RESEARCH_CODE  IENZQIKPVFGBNW-UHFFFAOYSA-N
#
#                                 canonical_smiles  mw_freebase
# 0  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 1  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 2  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 3  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41
# 4  COc1cc2nc(nc(N)c2cc1OC)N3CCN(CC3)C(=O)c4occc4       383.41

# %%
# Substance in plasma_renamed are unique
len(plasma), len(plasma['Substance'].drop_duplicates())
# Out:
# (873, 873)

# %%
# Pref_name in approved are not unique - some compounds with different chembl_id have same name
len(approved[['chembl_id', 'pref_name']].drop_duplicates()), len(approved[['pref_name']].drop_duplicates())
# Out:
# (3813, 3741)

# %%
# Find names with more than one chembl_id and are overlapping with plasma concentration data
approved_name_counts = approved[['chembl_id', 'pref_name','canonical_smiles']].drop_duplicates().groupby(by='pref_name').count()
approved_name_counts.loc[approved_name_counts['chembl_id']>1,:]

multiples = approved.loc[approved['pref_name'].isin(approved_name_counts.loc[approved_name_counts['chembl_id']>1,:].index),['chembl_id','pref_name','canonical_smiles']].drop_duplicates().sort_values(by='pref_name')

multiples_overlapping = approved.loc[(approved['pref_name'].isin(approved_name_counts.loc[approved_name_counts['chembl_id']>1,:].index))&(approved['pref_name'].isin(plasma['Substance'])),['chembl_id','pref_name','canonical_smiles']].drop_duplicates().sort_values(by='pref_name')

# %%
# Manually inspect these, easy to see which ones are hydrated in smiles
multiples_overlapping
# Out:
#             chembl_id         pref_name  \
# 455010  CHEMBL3544909       CALCIFEDIOL
# 269079     CHEMBL1040       CALCIFEDIOL
# 19577        CHEMBL14         CARBACHOL
# 254955      CHEMBL965         CARBACHOL
# 432690  CHEMBL1201236         CARBIDOPA
# 420439  CHEMBL1200748         CARBIDOPA
# 187236      CHEMBL680          CEFACLOR
# 427988  CHEMBL1201018          CEFACLOR
# 85505        CHEMBL88  CYCLOPHOSPHAMIDE
# 422118  CHEMBL1200796  CYCLOPHOSPHAMIDE
# 419218  CHEMBL1200699       DOXYCYCLINE
# 332484     CHEMBL1433       DOXYCYCLINE
# 406060    CHEMBL43708          IMIPENEM
# 207224      CHEMBL148          IMIPENEM
# 293794     CHEMBL1237        LISINOPRIL
# 288613   CHEMBL419213        LISINOPRIL
# 420966  CHEMBL1200751    MERCAPTOPURINE
# 317132     CHEMBL1425    MERCAPTOPURINE
# 292996     CHEMBL1228   OXYPHENBUTAZONE
# 456640  CHEMBL3989676   OXYPHENBUTAZONE
# 313933     CHEMBL1412        PIPERAZINE
# 457156  CHEMBL3990694        PIPERAZINE
# 456224  CHEMBL3833382        PRAJMALIUM
# 456253  CHEMBL3833412        PRAJMALIUM
# 457105  CHEMBL3989887        TACROLIMUS
# 21682    CHEMBL269732        TACROLIMUS
#
#                                                                                                                                                                      canonical_smiles
# 455010                                                                                                O.C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\\C(=C\\C=C/3\\C[C@@H](O)CCC3=C)\\CCC[C@]12C
# 269079                                                                                                  C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\\C(=C\\C=C/3\\C[C@@H](O)CCC3=C)\\CCC[C@]12C
# 19577                                                                                                                                                      [Cl-].C[N+](C)(C)CCOC(=O)N
# 254955                                                                                                                                                           C[N+](C)(C)CCOC(=O)N
# 432690                                                                                                                                              C[C@@](Cc1ccc(O)c(O)c1)(NN)C(=O)O
# 420439                                                                                                                                            O.C[C@@](Cc1ccc(O)c(O)c1)(NN)C(=O)O
# 187236                                                                                                                     N[C@@H](C(=O)N[C@H]1[C@H]2SCC(=C(N2C1=O)C(=O)O)Cl)c3ccccc3
# 427988                                                                                                                   O.N[C@@H](C(=O)N[C@H]1[C@H]2SCC(=C(N2C1=O)C(=O)O)Cl)c3ccccc3
# 85505                                                                                                                                                         ClCCN(CCCl)P1(=O)NCCCO1
# 422118                                                                                                                                                      O.ClCCN(CCCl)P1(=O)NCCCO1
# 419218                                                                                 O.C[C@@H]1[C@H]2[C@H](O)[C@H]3[C@H](N(C)C)C(=C(C(=O)N)C(=O)[C@@]3(O)C(=C2C(=O)c4c(O)cccc14)O)O
# 332484                                                                                   C[C@@H]1[C@H]2[C@H](O)[C@H]3[C@H](N(C)C)C(=C(C(=O)N)C(=O)[C@@]3(O)C(=C2C(=O)c4c(O)cccc14)O)O
# 406060                                                                                                                           O.C[C@@H](O)[C@@H]1[C@H]2CC(=C(N2C1=O)C(=O)O)SCCNC=N
# 207224                                                                                                                             C[C@@H](O)[C@@H]1[C@H]2CC(=C(N2C1=O)C(=O)O)SCCNC=N
# 293794                                                                                                                    NCCCC[C@H](N[C@@H](CCc1ccccc1)C(=O)O)C(=O)N2CCC[C@H]2C(=O)O
# 288613                                                                                                                O.O.NCCCC[C@H](N[C@@H](CCc1ccccc1)C(=O)O)C(=O)N2CCC[C@H]2C(=O)O
# 420966                                                                                                                                                            O.Sc1ncnc2nc[nH]c12
# 317132                                                                                                                                                              Sc1ncnc2nc[nH]c12
# 292996                                                                                                                                       CCCCC1C(=O)N(N(C1=O)c2ccc(O)cc2)c3ccccc3
# 456640                                                                                                                                     O.CCCCC1C(=O)N(N(C1=O)c2ccc(O)cc2)c3ccccc3
# 313933                                                                                                                                                                       C1CNCCN1
# 457156                                                                                               OC(=O)CC(O)(CC(=O)O)C(=O)O.OC(=O)CC(O)(CC(=O)O)C(=O)O.C1CNCCN1.C2CNCCN2.C3CNCCN3
# 456224                                                                                         CCC[N+]12[C@H](O)[C@@H](CC)[C@@H]3C[C@H]1[C@@H]4N(C)c5ccccc5[C@]46C[C@H]2[C@H]3[C@H]6O
# 456253                                                                                         CCC[N+]12[C@H](O)[C@@H](CC)[C@@H]3C[C@H]1[C@@H]4N(C)c5ccccc5[C@]46C[C@H]2[C@H]3[C@H]6O
# 457105  O.CO[C@@H]1C[C@@H](CC[C@H]1O)\\C=C(/C)\\[C@H]2OC(=O)[C@@H]3CCCCN3C(=O)C(=O)[C@]4(O)O[C@H]([C@H](C[C@@H](C)C\\C(=C\\[C@@H](CC=C)C(=O)C[C@H](O)[C@H]2C)\\C)OC)[C@H](C[C@H]4C)OC
# 21682     CO[C@@H]1C[C@@H](CC[C@H]1O)\\C=C(/C)\\[C@H]2OC(=O)[C@@H]3CCCCN3C(=O)C(=O)[C@]4(O)O[C@H]([C@H](C[C@@H](C)C\\C(=C\\[C@@H](CC=C)C(=O)C[C@H](O)[C@H]2C)\\C)OC)[C@H](C[C@H]4C)OC

# %%
# Here are the ones to keep
keep = ['CHEMBL269732','CHEMBL3833412','CHEMBL1412', 'CHEMBL1228', 'CHEMBL1425', 'CHEMBL1237', 'CHEMBL148', 'CHEMBL1433', 'CHEMBL88', 'CHEMBL680', 'CHEMBL1201236', 'CHEMBL965', 'CHEMBL1040']

# %%
# Remove all multiples
# Add back in the ones to keep

approved_unique = approved.loc[~approved['chembl_id'].isin(multiples['chembl_id']),['chembl_id', 'pref_name']].drop_duplicates()
approved_keep = approved.loc[approved['chembl_id'].isin(keep),['chembl_id','pref_name']].drop_duplicates()
approved_unique = pd.concat([approved_unique, approved_keep])

# %%
len(approved_unique)
# Out:
# 3700

# %%
pref_name_mappings = pd.merge(plasma, approved_unique, left_on = 'Substance', right_on='pref_name')
pref_name_mappings
# Out:
#          Substance Salts Synonym  \
# 0         ABACAVIR   NaN     NaN
# 1      ACAMPROSATE   NaN     NaN
# 2       ACEBUTOLOL   NaN     NaN
# 3    ACENOCOUMAROL   NaN     NaN
# 4    ACETAZOLAMIDE   NaN     NaN
# ..             ...   ...     ...
# 625       ZOLPIDEM   NaN     NaN
# 626      ZOMEPIRAC   NaN     NaN
# 627     ZONISAMIDE   NaN     NaN
# 628      ZOPICLONE   NaN     NaN
# 629       ZOTEPINE   NaN     NaN
#
#      Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit  \
# 0                                                                  3.90  NaN
# 1                                                                  0.70  NaN
# 2                                                                  2.00  NaN
# 3                                                                  0.50  NaN
# 4                                                                 20.00  NaN
# ..                                                                  ...  ...
# 625                                                                0.15  NaN
# 626                                                                4.00  NaN
# 627                                                               40.00  NaN
# 628                                                                0.05  NaN
# 629                                                                0.15  NaN
#
#          chembl_id      pref_name
# 0       CHEMBL1380       ABACAVIR
# 1    CHEMBL1201293    ACAMPROSATE
# 2        CHEMBL642     ACEBUTOLOL
# 3     CHEMBL397420  ACENOCOUMAROL
# 4         CHEMBL20  ACETAZOLAMIDE
# ..             ...            ...
# 625      CHEMBL911       ZOLPIDEM
# 626    CHEMBL19490      ZOMEPIRAC
# 627      CHEMBL750     ZONISAMIDE
# 628   CHEMBL135400      ZOPICLONE
# 629   CHEMBL285802       ZOTEPINE
#
# [630 rows x 7 columns]

# %%
# Currently unmapped, Substance name is not in mappings based on pref_name
unmapped1 = plasma.loc[~plasma['Substance'].isin(pref_name_mappings['Substance']),:]

# %%
unmapped1.head()
# Out:
#                Substance      Salts Synonym  \
# 4           ACETALDEHYDE        NaN     NaN
# 7                ACETONE        NaN     NaN
# 8          ACETYLDIGOXIN        NaN     NaN
# 9   ACETYLSALICYLIC ACID        NaN     NaN
# 14            ADIPIODONE  meglumine     NaN
#
#     Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit
# 4                                                              30.0000  NaN
# 7                                                              20.0000  NaN
# 8                                                               0.0008  NaN
# 9                                                             200.0000  NaN
# 14                                                           1200.0000  NaN

# %%
# Try synonym from plasma concentrations on chembl pref_name
synonym_pref_name_mappings_initial = pd.merge(unmapped1, approved[['pref_name', 'chembl_id','canonical_smiles']].drop_duplicates(), left_on='Synonym', right_on='pref_name').drop_duplicates().sort_values(by='Substance')
synonym_pref_name_mappings_initial = synonym_pref_name_mappings_initial.loc[~synonym_pref_name_mappings_initial['Synonym'].isnull(),:]

# %%
synonym_pref_name_mappings_initial
# Out:
#                            Substance Salts               Synonym  \
# 2030                     ALENDRONATE   NaN       ALENDRONIC ACID
# 2031                    AZAPROPAZONE   NaN               APAZONE
# 2032              DEXTROPROPOXYPHENE   NaN          PROPOXYPHENE
# 2033                      ETAMSYLATE   NaN           ETHAMSYLATE
# 2034                     INDOMETACIN   NaN          INDOMETHACIN
# 2035                      MESALAZINE   NaN            MESALAMINE
# 2037                      METAMIZOLE   NaN              DIPYRONE
# 2036                      METAMIZOLE   NaN              DIPYRONE
# 2038                     PAMIDRONATE   NaN       PAMIDRONIC ACID
# 2039                       PHENAZONE   NaN            ANTIPYRINE
# 2040                      RIFAMPICIN   NaN              RIFAMPIN
# 2041                      SALBUTAMOL   NaN             ALBUTEROL
# 2042                         SULTIAM   NaN             SULTHIAME
# 2043  THIOCYANATE FROM NITROPRUSSIDE   NaN  SODIUM NITROPRUSSIDE
# 2044                     TILUDRONATE   NaN       TILUDRONIC ACID
# 2045                       TIOTIXENE   NaN           THIOTHIXENE
#
#       Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit  \
# 2030                                                               0.265  NaN
# 2031                                                              90.000  NaN
# 2032                                                               0.500  NaN
# 2033                                                              20.000  NaN
# 2034                                                               3.000  NaN
# 2035                                                               1.000  NaN
# 2037                                                              10.000  NaN
# 2036                                                              10.000  NaN
# 2038                                                               0.250  NaN
# 2039                                                              25.000  NaN
# 2040                                                              10.000  NaN
# 2041                                                               0.020  NaN
# 2042                                                               8.000  NaN
# 2043                                                              30.000  NaN
# 2044                                                               1.500  NaN
# 2045                                                               0.014  NaN
#
#                  pref_name      chembl_id  \
# 2030       ALENDRONIC ACID      CHEMBL870
# 2031               APAZONE  CHEMBL1565476
# 2032          PROPOXYPHENE  CHEMBL1213351
# 2033           ETHAMSYLATE  CHEMBL1514715
# 2034          INDOMETHACIN        CHEMBL6
# 2035            MESALAMINE      CHEMBL704
# 2037              DIPYRONE  CHEMBL3989803
# 2036              DIPYRONE   CHEMBL461522
# 2038       PAMIDRONIC ACID      CHEMBL834
# 2039            ANTIPYRINE   CHEMBL277474
# 2040              RIFAMPIN   CHEMBL374478
# 2041             ALBUTEROL      CHEMBL714
# 2042             SULTHIAME   CHEMBL328560
# 2043  SODIUM NITROPRUSSIDE   CHEMBL136478
# 2044       TILUDRONIC ACID     CHEMBL1350
# 2045           THIOTHIXENE     CHEMBL1201
#
#                                                                                                                                                           canonical_smiles
# 2030                                                                                                                                          NCCCC(O)(P(=O)(O)O)P(=O)(O)O
# 2031                                                                                                                               CCCC1C(=O)N2N(C1=O)c3cc(C)ccc3N=C2N(C)C
# 2032                                                                                                                      CCC(=O)O[C@@](Cc1ccccc1)([C@H](C)CN(C)C)c2ccccc2
# 2033                                                                                                                                        CCNCC.Oc1ccc(O)c(c1)S(=O)(=O)O
# 2034                                                                                                                        COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c3ccc(Cl)cc3
# 2035                                                                                                                                                  Nc1ccc(O)c(c1)C(=O)O
# 2037                                                                                                                  O.[Na+].CN(CS(=O)(=O)[O-])C1=C(C)N(C)N(C1=O)c2ccccc2
# 2036                                                                                                                             CN(CS(=O)(=O)O)C1=C(C)N(C)N(C1=O)c2ccccc2
# 2038                                                                                                                                           NCCC(O)(P(=O)(O)O)P(=O)(O)O
# 2039                                                                                                                                              CN1N(C(=O)C=C1C)c2ccccc2
# 2040  CO[C@H]1\\C=C\\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(NC(=O)\\C(=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(=O)C)[C@@H]1C)\\C)c(\\C=N\\N5CCN(C)CC5)c(O)c4c3C2=O
# 2041                                                                                                                                         CC(C)(C)NCC(O)c1ccc(O)c(CO)c1
# 2042                                                                                                                                    NS(=O)(=O)c1ccc(cc1)N2CCCCS2(=O)=O
# 2043                                                                                                                                                                   NaN
# 2044                                                                                                                                    OP(=O)(O)C(Sc1ccc(Cl)cc1)P(=O)(O)O
# 2045                                                                                                             CN(C)S(=O)(=O)c1ccc2Sc3ccccc3\\C(=C\\CCN4CCN(C)CC4)\\c2c1

# %%
# Need to drop CHEMBL3989803, not sure about CHEMBL136478 either

# %%
synonym_pref_name_mappings = synonym_pref_name_mappings_initial.loc[~synonym_pref_name_mappings_initial['chembl_id'].isin(['CHEMBL3989803','CHEMBL136478']),['Substance','pref_name', 'Blood-plasma concentration (mg/L) therapeutic (normal) upper limit', 'chembl_id']]

# %%
all_mappings = pd.concat([synonym_pref_name_mappings,pref_name_mappings],sort=False,ignore_index=True)

# %%
all_mappings.loc[all_mappings['pref_name']=='DIPYRONE',:]
# Out:
#     Substance pref_name  \
# 6  METAMIZOLE  DIPYRONE
#
#    Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 6                                                                10.0
#
#       chembl_id Salts Synonym Unit
# 6  CHEMBL461522   NaN     NaN  NaN

# %%
unmapped2 = plasma.loc[(~plasma['Substance'].isin(all_mappings['Substance']))&(~plasma['Synonym'].isin(all_mappings['pref_name'])),:]

# %%
len(unmapped2)
# Out:
# 229

# %%
all_mappings.head()
# Out:
#             Substance        pref_name  \
# 0         ALENDRONATE  ALENDRONIC ACID
# 1        AZAPROPAZONE          APAZONE
# 2  DEXTROPROPOXYPHENE     PROPOXYPHENE
# 3          ETAMSYLATE      ETHAMSYLATE
# 4         INDOMETACIN     INDOMETHACIN
#
#    Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                               0.265
# 1                                                              90.000
# 2                                                               0.500
# 3                                                              20.000
# 4                                                               3.000
#
#        chembl_id Salts Synonym Unit
# 0      CHEMBL870   NaN     NaN  NaN
# 1  CHEMBL1565476   NaN     NaN  NaN
# 2  CHEMBL1213351   NaN     NaN  NaN
# 3  CHEMBL1514715   NaN     NaN  NaN
# 4        CHEMBL6   NaN     NaN  NaN

# %% [markdown]
# # Third round

# %%
# Plasma Substance to ChEMBL synonyms
substance_synonyms_mappings = pd.merge(unmapped2, approved, left_on='Substance', right_on='synonyms')[['pref_name','Substance','syn_type','chembl_id','canonical_smiles', 'Blood-plasma concentration (mg/L) therapeutic (normal) upper limit', 'Unit']].drop_duplicates()

# %%
# Inspect manually and decide which ones to drop
substance_synonyms_mappings.sort_values(by='Substance')
# Out:
#                          pref_name             Substance    syn_type  \
# 869                   FLUOROURACIL        5-FLUOROURACIL       OTHER
# 3                          ASPIRIN  ACETYLSALICYLIC ACID  TRADE_NAME
# 0                          ASPIRIN  ACETYLSALICYLIC ACID         ATC
# 1                          ASPIRIN  ACETYLSALICYLIC ACID         INN
# 2                          ASPIRIN  ACETYLSALICYLIC ACID       OTHER
# 304                     IODIPAMIDE            ADIPIODONE         ATC
# 305                     IODIPAMIDE            ADIPIODONE         BAN
# 306                     IODIPAMIDE            ADIPIODONE         INN
# 307                     IODIPAMIDE            ADIPIODONE         JAN
# 328                METHYLPROMAZINE           ALIMEMAZINE         ATC
# 329                METHYLPROMAZINE           ALIMEMAZINE         BAN
# 330                METHYLPROMAZINE           ALIMEMAZINE         INN
# 350                    AMINOPYRINE        AMINOPHENAZONE         INN
# 349                    AMINOPYRINE        AMINOPHENAZONE         ATC
# 387       AMMONIA SOLUTION, STRONG               AMMONIA         INN
# 392                     INAMRINONE              AMRINONE         ATC
# 393                     INAMRINONE              AMRINONE         BAN
# 394                     INAMRINONE              AMRINONE         INN
# 395                     INAMRINONE              AMRINONE         JAN
# 396                     INAMRINONE              AMRINONE       OTHER
# 497            BENDROFLUMETHIAZIDE        BENDROFLUAZIDE         BAN
# 513                  BETA CAROTENE          BETACAROTENE         USP
# 511                  BETA CAROTENE          BETACAROTENE       OTHER
# 512                  BETA CAROTENE          BETACAROTENE        USAN
# 509                  BETA CAROTENE          BETACAROTENE         FDA
# 507                  BETA CAROTENE          BETACAROTENE         ATC
# 510                  BETA CAROTENE          BETACAROTENE         INN
# 508                  BETA CAROTENE          BETACAROTENE         BNF
# 577          CANDESARTAN CILEXETIL           CANDESARTAN         BAN
# 588                     CEPHALEXIN             CEFALEXIN         ATC
# 589                     CEPHALEXIN             CEFALEXIN         BAN
# 590                     CEPHALEXIN             CEFALEXIN         INN
# 678                     CEPHALEXIN             CEFALEXIN         BNF
# 679                     CEPHALEXIN             CEFALEXIN         JAN
# 687           CEFPODOXIME PROXETIL           CEFPODOXIME         INN
# 686           CEFPODOXIME PROXETIL           CEFPODOXIME         BNF
# 685           CEFPODOXIME PROXETIL           CEFPODOXIME         BAN
# 684           CEFPODOXIME PROXETIL           CEFPODOXIME         ATC
# 713                 CHLORTHALIDONE         CHLORTALIDONE         BAN
# 714                 CHLORTHALIDONE         CHLORTALIDONE         BNF
# 715                 CHLORTHALIDONE         CHLORTALIDONE         INN
# 716                 CHLORTHALIDONE         CHLORTALIDONE         JAN
# 712                 CHLORTHALIDONE         CHLORTALIDONE         ATC
# 777                      DICUMAROL            DICOUMAROL         ATC
# 778                      DICUMAROL            DICOUMAROL         DCF
# 779                      DICUMAROL            DICOUMAROL         INN
# 840   DROTRECOGIN ALFA (ACTIVATED)      DROTRECOGIN ALFA         BNF
# 841   DROTRECOGIN ALFA (ACTIVATED)      DROTRECOGIN ALFA       OTHER
# 844                    FLOXACILLIN        FLUCLOXACILLIN         INN
# 842                    FLOXACILLIN        FLUCLOXACILLIN         ATC
# 843                    FLOXACILLIN        FLUCLOXACILLIN         BAN
# 974                      GLYBURIDE         GLIBENCLAMIDE         ATC
# 975                      GLYBURIDE         GLIBENCLAMIDE         BAN
# 976                      GLYBURIDE         GLIBENCLAMIDE         BNF
# 977                      GLYBURIDE         GLIBENCLAMIDE         DCF
# 978                      GLYBURIDE         GLIBENCLAMIDE         INN
# 979                      GLYBURIDE         GLIBENCLAMIDE         JAN
# 1387                    ERLOSAMIDE            LACOSAMIDE        USAN
# 1386                    ERLOSAMIDE            LACOSAMIDE  TRADE_NAME
# 1385                    ERLOSAMIDE            LACOSAMIDE         INN
# 1384                    ERLOSAMIDE            LACOSAMIDE         FDA
# 1383                    ERLOSAMIDE            LACOSAMIDE         BNF
# 1382                    ERLOSAMIDE            LACOSAMIDE         ATC
# 1496          LEVOMETHADYL ACETATE     LEVACETYLMETHADOL         ATC
# 1497          LEVOMETHADYL ACETATE     LEVACETYLMETHADOL         INN
# 1506                   TRICHLORFON           METRIFONATE         ATC
# 1507                   TRICHLORFON           METRIFONATE         BAN
# 1508                   TRICHLORFON           METRIFONATE         BNF
# 1509                   TRICHLORFON           METRIFONATE         INN
# 1548                        NIACIN        NICOTINIC ACID         INN
# 1549                        NIACIN        NICOTINIC ACID         JAN
# 1546                        NIACIN        NICOTINIC ACID         ATC
# 1547                        NIACIN        NICOTINIC ACID         BNF
# 1687                 ACETAMINOPHEN           PARACETAMOL  TRADE_NAME
# 1686                 ACETAMINOPHEN           PARACETAMOL         INN
# 1685                 ACETAMINOPHEN           PARACETAMOL         DCF
# 1682                 ACETAMINOPHEN           PARACETAMOL         ATC
# 1683                 ACETAMINOPHEN           PARACETAMOL         BAN
# 1684                 ACETAMINOPHEN           PARACETAMOL         BNF
# 2036                CARBETAPENTANE         PENTOXYVERINE         ATC
# 2037                CARBETAPENTANE         PENTOXYVERINE         BAN
# 2038                CARBETAPENTANE         PENTOXYVERINE         INN
# 2081        CARBETAPENTANE CITRATE         PENTOXYVERINE         DCF
# 2094                    MEPERIDINE             PETHIDINE         INN
# 2137      MEPERIDINE HYDROCHLORIDE             PETHIDINE  TRADE_NAME
# 2092                    MEPERIDINE             PETHIDINE         ATC
# 2093                    MEPERIDINE             PETHIDINE         BAN
# 2143         PIPOTIAZINE PALMITATE           PIPOTIAZINE         ATC
# 2144         PIPOTIAZINE PALMITATE           PIPOTIAZINE         BAN
# 2145         PIPOTIAZINE PALMITATE           PIPOTIAZINE         INN
# 2149                 CHLOROGUANIDE             PROGUANIL         ATC
# 2150                 CHLOROGUANIDE             PROGUANIL         BAN
# 2151                 CHLOROGUANIDE             PROGUANIL         FDA
# 2152                 CHLOROGUANIDE             PROGUANIL         INN
# 2177   CHLOROGUANIDE HYDROCHLORIDE             PROGUANIL         DCF
# 2182                  BUTABARBITAL       SECBUTABARBITAL         BAN
# 2183                  BUTABARBITAL       SECBUTABARBITAL         INN
# 2188               CHOLECALCIFEROL             VITAMIN D       OTHER
# 2212                ERGOCALCIFEROL             VITAMIN D  TRADE_NAME
#
#           chembl_id  \
# 869       CHEMBL185
# 3          CHEMBL25
# 0          CHEMBL25
# 1          CHEMBL25
# 2          CHEMBL25
# 304   CHEMBL1165268
# 305   CHEMBL1165268
# 306   CHEMBL1165268
# 307   CHEMBL1165268
# 328       CHEMBL829
# 329       CHEMBL829
# 330       CHEMBL829
# 350    CHEMBL288470
# 349    CHEMBL288470
# 387   CHEMBL1160819
# 392     CHEMBL12856
# 393     CHEMBL12856
# 394     CHEMBL12856
# 395     CHEMBL12856
# 396     CHEMBL12856
# 497      CHEMBL1684
# 513      CHEMBL1293
# 511      CHEMBL1293
# 512      CHEMBL1293
# 509      CHEMBL1293
# 507      CHEMBL1293
# 510      CHEMBL1293
# 508      CHEMBL1293
# 577      CHEMBL1014
# 588      CHEMBL1727
# 589      CHEMBL1727
# 590      CHEMBL1727
# 678   CHEMBL1200544
# 679   CHEMBL1200544
# 687   CHEMBL1201016
# 686   CHEMBL1201016
# 685   CHEMBL1201016
# 684   CHEMBL1201016
# 713      CHEMBL1055
# 714      CHEMBL1055
# 715      CHEMBL1055
# 716      CHEMBL1055
# 712      CHEMBL1055
# 777      CHEMBL1466
# 778      CHEMBL1466
# 779      CHEMBL1466
# 840   CHEMBL2109065
# 841   CHEMBL2109065
# 844    CHEMBL222645
# 842    CHEMBL222645
# 843    CHEMBL222645
# 974       CHEMBL472
# 975       CHEMBL472
# 976       CHEMBL472
# 977       CHEMBL472
# 978       CHEMBL472
# 979       CHEMBL472
# 1387    CHEMBL58323
# 1386    CHEMBL58323
# 1385    CHEMBL58323
# 1384    CHEMBL58323
# 1383    CHEMBL58323
# 1382    CHEMBL58323
# 1496     CHEMBL1514
# 1497     CHEMBL1514
# 1506   CHEMBL167150
# 1507   CHEMBL167150
# 1508   CHEMBL167150
# 1509   CHEMBL167150
# 1548      CHEMBL573
# 1549      CHEMBL573
# 1546      CHEMBL573
# 1547      CHEMBL573
# 1687      CHEMBL112
# 1686      CHEMBL112
# 1685      CHEMBL112
# 1682      CHEMBL112
# 1683      CHEMBL112
# 1684      CHEMBL112
# 2036    CHEMBL73234
# 2037    CHEMBL73234
# 2038    CHEMBL73234
# 2081  CHEMBL1256696
# 2094      CHEMBL607
# 2137     CHEMBL1701
# 2092      CHEMBL607
# 2093      CHEMBL607
# 2143  CHEMBL2106439
# 2144  CHEMBL2106439
# 2145  CHEMBL2106439
# 2149     CHEMBL1377
# 2150     CHEMBL1377
# 2151     CHEMBL1377
# 2152     CHEMBL1377
# 2177  CHEMBL1201059
# 2182      CHEMBL449
# 2183      CHEMBL449
# 2188     CHEMBL1042
# 2212     CHEMBL1536
#
#                                                                                   canonical_smiles  \
# 869                                                                               FC1=CNC(=O)NC1=O
# 3                                                                            CC(=O)Oc1ccccc1C(=O)O
# 0                                                                            CC(=O)Oc1ccccc1C(=O)O
# 1                                                                            CC(=O)Oc1ccccc1C(=O)O
# 2                                                                            CC(=O)Oc1ccccc1C(=O)O
# 304                                 OC(=O)c1c(I)cc(I)c(NC(=O)CCCCC(=O)Nc2c(I)cc(I)c(C(=O)O)c2I)c1I
# 305                                 OC(=O)c1c(I)cc(I)c(NC(=O)CCCCC(=O)Nc2c(I)cc(I)c(C(=O)O)c2I)c1I
# 306                                 OC(=O)c1c(I)cc(I)c(NC(=O)CCCCC(=O)Nc2c(I)cc(I)c(C(=O)O)c2I)c1I
# 307                                 OC(=O)c1c(I)cc(I)c(NC(=O)CCCCC(=O)Nc2c(I)cc(I)c(C(=O)O)c2I)c1I
# 328                                                                CC(CN(C)C)CN1c2ccccc2Sc3ccccc13
# 329                                                                CC(CN(C)C)CN1c2ccccc2Sc3ccccc13
# 330                                                                CC(CN(C)C)CN1c2ccccc2Sc3ccccc13
# 350                                                                CN(C)C1=C(C)N(C)N(C1=O)c2ccccc2
# 349                                                                CN(C)C1=C(C)N(C)N(C1=O)c2ccccc2
# 387                                                                                              N
# 392                                                                        NC1=CC(=CNC1=O)c2ccncc2
# 393                                                                        NC1=CC(=CNC1=O)c2ccncc2
# 394                                                                        NC1=CC(=CNC1=O)c2ccncc2
# 395                                                                        NC1=CC(=CNC1=O)c2ccncc2
# 396                                                                        NC1=CC(=CNC1=O)c2ccncc2
# 497                                            NS(=O)(=O)c1cc2c(NC(Cc3ccccc3)NS2(=O)=O)cc1C(F)(F)F
# 513   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 511   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 512   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 509   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 507   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 510   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 508   C\\C(=C/C=C/C=C(\\C)/C=C/C=C(\\C)/C=C/C1=C(C)CCCC1(C)C)\\C=C\\C=C(/C)\\C=C\\C2=C(C)CCCC2(C)C
# 577                       CCOc1nc2cccc(C(=O)OC(C)OC(=O)OC3CCCCC3)c2n1Cc4ccc(cc4)c5ccccc5c6nn[nH]n6
# 588                                     CC1=C(N2[C@H](SC1)[C@H](NC(=O)[C@H](N)c3ccccc3)C2=O)C(=O)O
# 589                                     CC1=C(N2[C@H](SC1)[C@H](NC(=O)[C@H](N)c3ccccc3)C2=O)C(=O)O
# 590                                     CC1=C(N2[C@H](SC1)[C@H](NC(=O)[C@H](N)c3ccccc3)C2=O)C(=O)O
# 678                                   O.CC1=C(N2[C@H](SC1)[C@H](NC(=O)[C@H](N)c3ccccc3)C2=O)C(=O)O
# 679                                   O.CC1=C(N2[C@H](SC1)[C@H](NC(=O)[C@H](N)c3ccccc3)C2=O)C(=O)O
# 687             COCC1=C(N2[C@H](SC1)[C@H](NC(=O)\\C(=N/OC)\\c3csc(N)n3)C2=O)C(=O)OC(C)OC(=O)OC(C)C
# 686             COCC1=C(N2[C@H](SC1)[C@H](NC(=O)\\C(=N/OC)\\c3csc(N)n3)C2=O)C(=O)OC(C)OC(=O)OC(C)C
# 685             COCC1=C(N2[C@H](SC1)[C@H](NC(=O)\\C(=N/OC)\\c3csc(N)n3)C2=O)C(=O)OC(C)OC(=O)OC(C)C
# 684             COCC1=C(N2[C@H](SC1)[C@H](NC(=O)\\C(=N/OC)\\c3csc(N)n3)C2=O)C(=O)OC(C)OC(=O)OC(C)C
# 713                                                     NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 714                                                     NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 715                                                     NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 716                                                     NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 712                                                     NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 777                                                    OC1=C(CC2=C(O)c3ccccc3OC2=O)C(=O)Oc4ccccc14
# 778                                                    OC1=C(CC2=C(O)c3ccccc3OC2=O)C(=O)Oc4ccccc14
# 779                                                    OC1=C(CC2=C(O)c3ccccc3OC2=O)C(=O)Oc4ccccc14
# 840                                                                                            NaN
# 841                                                                                            NaN
# 844                          Cc1onc(c1C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4c(F)cccc4Cl
# 842                          Cc1onc(c1C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4c(F)cccc4Cl
# 843                          Cc1onc(c1C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4c(F)cccc4Cl
# 974                                       COc1ccc(Cl)cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3
# 975                                       COc1ccc(Cl)cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3
# 976                                       COc1ccc(Cl)cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3
# 977                                       COc1ccc(Cl)cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3
# 978                                       COc1ccc(Cl)cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3
# 979                                       COc1ccc(Cl)cc1C(=O)NCCc2ccc(cc2)S(=O)(=O)NC(=O)NC3CCCCC3
# 1387                                                             COC[C@@H](NC(=O)C)C(=O)NCc1ccccc1
# 1386                                                             COC[C@@H](NC(=O)C)C(=O)NCc1ccccc1
# 1385                                                             COC[C@@H](NC(=O)C)C(=O)NCc1ccccc1
# 1384                                                             COC[C@@H](NC(=O)C)C(=O)NCc1ccccc1
# 1383                                                             COC[C@@H](NC(=O)C)C(=O)NCc1ccccc1
# 1382                                                             COC[C@@H](NC(=O)C)C(=O)NCc1ccccc1
# 1496                                           CC[C@H](OC(=O)C)C(C[C@H](C)N(C)C)(c1ccccc1)c2ccccc2
# 1497                                           CC[C@H](OC(=O)C)C(C[C@H](C)N(C)C)(c1ccccc1)c2ccccc2
# 1506                                                                    COP(=O)(OC)C(O)C(Cl)(Cl)Cl
# 1507                                                                    COP(=O)(OC)C(O)C(Cl)(Cl)Cl
# 1508                                                                    COP(=O)(OC)C(O)C(Cl)(Cl)Cl
# 1509                                                                    COP(=O)(OC)C(O)C(Cl)(Cl)Cl
# 1548                                                                                OC(=O)c1cccnc1
# 1549                                                                                OC(=O)c1cccnc1
# 1546                                                                                OC(=O)c1cccnc1
# 1547                                                                                OC(=O)c1cccnc1
# 1687                                                                            CC(=O)Nc1ccc(O)cc1
# 1686                                                                            CC(=O)Nc1ccc(O)cc1
# 1685                                                                            CC(=O)Nc1ccc(O)cc1
# 1682                                                                            CC(=O)Nc1ccc(O)cc1
# 1683                                                                            CC(=O)Nc1ccc(O)cc1
# 1684                                                                            CC(=O)Nc1ccc(O)cc1
# 2036                                                           CCN(CC)CCOCCOC(=O)C1(CCCC1)c2ccccc2
# 2037                                                           CCN(CC)CCOCCOC(=O)C1(CCCC1)c2ccccc2
# 2038                                                           CCN(CC)CCOCCOC(=O)C1(CCCC1)c2ccccc2
# 2081                                CCN(CC)CCOCCOC(=O)C1(CCCC1)c2ccccc2.OC(=O)CC(O)(CC(=O)O)C(=O)O
# 2094                                                                 CCOC(=O)C1(CCN(C)CC1)c2ccccc2
# 2137                                                              Cl.CCOC(=O)C1(CCN(C)CC1)c2ccccc2
# 2092                                                                 CCOC(=O)C1(CCN(C)CC1)c2ccccc2
# 2093                                                                 CCOC(=O)C1(CCN(C)CC1)c2ccccc2
# 2143                      CCCCCCCCCCCCCCCC(=O)OCCC1CCN(CCCN2c3ccccc3Sc4ccc(cc24)S(=O)(=O)N(C)C)CC1
# 2144                      CCCCCCCCCCCCCCCC(=O)OCCC1CCN(CCCN2c3ccccc3Sc4ccc(cc24)S(=O)(=O)N(C)C)CC1
# 2145                      CCCCCCCCCCCCCCCC(=O)OCCC1CCN(CCCN2c3ccccc3Sc4ccc(cc24)S(=O)(=O)N(C)C)CC1
# 2149                                                                CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1
# 2150                                                                CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1
# 2151                                                                CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1
# 2152                                                                CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1
# 2177                                                             Cl.CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1
# 2182                                                                  CCC(C)C1(CC)C(=O)NC(=O)NC1=O
# 2183                                                                  CCC(C)C1(CC)C(=O)NC(=O)NC1=O
# 2188                   CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2\\C(=C\\C=C/3\\C[C@@H](O)CCC3=C)\\CCC[C@]12C
# 2212      CC(C)[C@@H](C)\\C=C\\[C@@H](C)[C@H]1CC[C@H]2\\C(=C\\C=C/3\\C[C@@H](O)CCC3=C)\\CCC[C@]12C
#
#       Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit
# 869                                                                0.300  NaN
# 3                                                                200.000  NaN
# 0                                                                200.000  NaN
# 1                                                                200.000  NaN
# 2                                                                200.000  NaN
# 304                                                             1200.000  NaN
# 305                                                             1200.000  NaN
# 306                                                             1200.000  NaN
# 307                                                             1200.000  NaN
# 328                                                                0.400  NaN
# 329                                                                0.400  NaN
# 330                                                                0.400  NaN
# 350                                                               20.000  NaN
# 349                                                               20.000  NaN
# 387                                                                1.700  NaN
# 392                                                                4.000  NaN
# 393                                                                4.000  NaN
# 394                                                                4.000  NaN
# 395                                                                4.000  NaN
# 396                                                                4.000  NaN
# 497                                                                0.100  NaN
# 513                                                                6.000  NaN
# 511                                                                6.000  NaN
# 512                                                                6.000  NaN
# 509                                                                6.000  NaN
# 507                                                                6.000  NaN
# 510                                                                6.000  NaN
# 508                                                                6.000  NaN
# 577                                                                0.180  NaN
# 588                                                               65.000  NaN
# 589                                                               65.000  NaN
# 590                                                               65.000  NaN
# 678                                                               65.000  NaN
# 679                                                               65.000  NaN
# 687                                                                7.000  NaN
# 686                                                                7.000  NaN
# 685                                                                7.000  NaN
# 684                                                                7.000  NaN
# 713                                                                1.400  NaN
# 714                                                                1.400  NaN
# 715                                                                1.400  NaN
# 716                                                                1.400  NaN
# 712                                                                1.400  NaN
# 777                                                               30.000  NaN
# 778                                                               30.000  NaN
# 779                                                               30.000  NaN
# 840                                                                0.072  NaN
# 841                                                                0.072  NaN
# 844                                                               40.000  NaN
# 842                                                               40.000  NaN
# 843                                                               40.000  NaN
# 974                                                                0.200  NaN
# 975                                                                0.200  NaN
# 976                                                                0.200  NaN
# 977                                                                0.200  NaN
# 978                                                                0.200  NaN
# 979                                                                0.200  NaN
# 1387                                                              10.000  NaN
# 1386                                                              10.000  NaN
# 1385                                                              10.000  NaN
# 1384                                                              10.000  NaN
# 1383                                                              10.000  NaN
# 1382                                                              10.000  NaN
# 1496                                                               0.060  NaN
# 1497                                                               0.060  NaN
# 1506                                                               3.600  NaN
# 1507                                                               3.600  NaN
# 1508                                                               3.600  NaN
# 1509                                                               3.600  NaN
# 1548                                                              18.000  NaN
# 1549                                                              18.000  NaN
# 1546                                                              18.000  NaN
# 1547                                                              18.000  NaN
# 1687                                                              25.000  NaN
# 1686                                                              25.000  NaN
# 1685                                                              25.000  NaN
# 1682                                                              25.000  NaN
# 1683                                                              25.000  NaN
# 1684                                                              25.000  NaN
# 2036                                                               0.180  NaN
# 2037                                                               0.180  NaN
# 2038                                                               0.180  NaN
# 2081                                                               0.180  NaN
# 2094                                                               0.800  NaN
# 2137                                                               0.800  NaN
# 2092                                                               0.800  NaN
# 2093                                                               0.800  NaN
# 2143                                                               0.060  NaN
# 2144                                                               0.060  NaN
# 2145                                                               0.060  NaN
# 2149                                                               0.150  NaN
# 2150                                                               0.150  NaN
# 2151                                                               0.150  NaN
# 2152                                                               0.150  NaN
# 2177                                                               0.150  NaN
# 2182                                                              15.000  NaN
# 2183                                                              15.000  NaN
# 2188                                                               0.090  NaN
# 2212                                                               0.090  NaN

# %%
to_drop = ['CHEMBL1200544','CHEMBL1256696', 'CHEMBL1701', 'CHEMBL1201059', 'CHEMBL1536']
substance_synonyms_mappings_to_add = substance_synonyms_mappings.loc[~substance_synonyms_mappings['chembl_id'].isin(to_drop),all_mappings.columns].drop_duplicates()
# Out:
# /scratch/ias41/envs/release/lib/python3.6/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
substance_synonyms_mappings_to_add
# Out:
#                  Substance                     pref_name  \
# 0     ACETYLSALICYLIC ACID                       ASPIRIN
# 304             ADIPIODONE                    IODIPAMIDE
# 328            ALIMEMAZINE               METHYLPROMAZINE
# 349         AMINOPHENAZONE                   AMINOPYRINE
# 387                AMMONIA      AMMONIA SOLUTION, STRONG
# 392               AMRINONE                    INAMRINONE
# 497         BENDROFLUAZIDE           BENDROFLUMETHIAZIDE
# 507           BETACAROTENE                 BETA CAROTENE
# 577            CANDESARTAN         CANDESARTAN CILEXETIL
# 588              CEFALEXIN                    CEPHALEXIN
# 684            CEFPODOXIME          CEFPODOXIME PROXETIL
# 712          CHLORTALIDONE                CHLORTHALIDONE
# 777             DICOUMAROL                     DICUMAROL
# 840       DROTRECOGIN ALFA  DROTRECOGIN ALFA (ACTIVATED)
# 842         FLUCLOXACILLIN                   FLOXACILLIN
# 869         5-FLUOROURACIL                  FLUOROURACIL
# 974          GLIBENCLAMIDE                     GLYBURIDE
# 1382            LACOSAMIDE                    ERLOSAMIDE
# 1496     LEVACETYLMETHADOL          LEVOMETHADYL ACETATE
# 1506           METRIFONATE                   TRICHLORFON
# 1546        NICOTINIC ACID                        NIACIN
# 1682           PARACETAMOL                 ACETAMINOPHEN
# 2036         PENTOXYVERINE                CARBETAPENTANE
# 2092             PETHIDINE                    MEPERIDINE
# 2143           PIPOTIAZINE         PIPOTIAZINE PALMITATE
# 2149             PROGUANIL                 CHLOROGUANIDE
# 2182       SECBUTABARBITAL                  BUTABARBITAL
# 2188             VITAMIN D               CHOLECALCIFEROL
#
#       Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                                200.000
# 304                                                             1200.000
# 328                                                                0.400
# 349                                                               20.000
# 387                                                                1.700
# 392                                                                4.000
# 497                                                                0.100
# 507                                                                6.000
# 577                                                                0.180
# 588                                                               65.000
# 684                                                                7.000
# 712                                                                1.400
# 777                                                               30.000
# 840                                                                0.072
# 842                                                               40.000
# 869                                                                0.300
# 974                                                                0.200
# 1382                                                              10.000
# 1496                                                               0.060
# 1506                                                               3.600
# 1546                                                              18.000
# 1682                                                              25.000
# 2036                                                               0.180
# 2092                                                               0.800
# 2143                                                               0.060
# 2149                                                               0.150
# 2182                                                              15.000
# 2188                                                               0.090
#
#           chembl_id  Salts  Synonym Unit
# 0          CHEMBL25    NaN      NaN  NaN
# 304   CHEMBL1165268    NaN      NaN  NaN
# 328       CHEMBL829    NaN      NaN  NaN
# 349    CHEMBL288470    NaN      NaN  NaN
# 387   CHEMBL1160819    NaN      NaN  NaN
# 392     CHEMBL12856    NaN      NaN  NaN
# 497      CHEMBL1684    NaN      NaN  NaN
# 507      CHEMBL1293    NaN      NaN  NaN
# 577      CHEMBL1014    NaN      NaN  NaN
# 588      CHEMBL1727    NaN      NaN  NaN
# 684   CHEMBL1201016    NaN      NaN  NaN
# 712      CHEMBL1055    NaN      NaN  NaN
# 777      CHEMBL1466    NaN      NaN  NaN
# 840   CHEMBL2109065    NaN      NaN  NaN
# 842    CHEMBL222645    NaN      NaN  NaN
# 869       CHEMBL185    NaN      NaN  NaN
# 974       CHEMBL472    NaN      NaN  NaN
# 1382    CHEMBL58323    NaN      NaN  NaN
# 1496     CHEMBL1514    NaN      NaN  NaN
# 1506   CHEMBL167150    NaN      NaN  NaN
# 1546      CHEMBL573    NaN      NaN  NaN
# 1682      CHEMBL112    NaN      NaN  NaN
# 2036    CHEMBL73234    NaN      NaN  NaN
# 2092      CHEMBL607    NaN      NaN  NaN
# 2143  CHEMBL2106439    NaN      NaN  NaN
# 2149     CHEMBL1377    NaN      NaN  NaN
# 2182      CHEMBL449    NaN      NaN  NaN
# 2188     CHEMBL1042    NaN      NaN  NaN

# %%
len(all_mappings)
# Out:
# 644

# %%
all_mappings = pd.concat([all_mappings, substance_synonyms_mappings_to_add], sort=False,ignore_index=True).drop_duplicates()

# %%
len(all_mappings)
# Out:
# 672

# %%
all_mappings.head()
# Out:
#             Substance        pref_name  \
# 0         ALENDRONATE  ALENDRONIC ACID
# 1        AZAPROPAZONE          APAZONE
# 2  DEXTROPROPOXYPHENE     PROPOXYPHENE
# 3          ETAMSYLATE      ETHAMSYLATE
# 4         INDOMETACIN     INDOMETHACIN
#
#    Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                               0.265
# 1                                                              90.000
# 2                                                               0.500
# 3                                                              20.000
# 4                                                               3.000
#
#        chembl_id Salts Synonym Unit
# 0      CHEMBL870   NaN     NaN  NaN
# 1  CHEMBL1565476   NaN     NaN  NaN
# 2  CHEMBL1213351   NaN     NaN  NaN
# 3  CHEMBL1514715   NaN     NaN  NaN
# 4        CHEMBL6   NaN     NaN  NaN

# %% [markdown]
# # Round 4

# %%
# Substance to compound name
round4_mappings = pd.merge(unmapped2, approved, left_on='Substance',right_on='compound_name')

# %%
round4_mappings
# Out:
#         Substance Salts Synonym  \
# 0   CHLORTALIDONE   NaN     NaN
# 1   CHLORTALIDONE   NaN     NaN
# 2   CHLORTALIDONE   NaN     NaN
# 3   CHLORTALIDONE   NaN     NaN
# 4   CHLORTALIDONE   NaN     NaN
# 5   CHLORTALIDONE   NaN     NaN
# 6   CHLORTALIDONE   NaN     NaN
# 7   CHLORTALIDONE   NaN     NaN
# 8   CHLORTALIDONE   NaN     NaN
# 9   CHLORTALIDONE   NaN     NaN
# 10  CHLORTALIDONE   NaN     NaN
# 11  CHLORTALIDONE   NaN     NaN
# 12  CHLORTALIDONE   NaN     NaN
# 13  PIPERACILLINE   NaN     NaN
# 14  PIPERACILLINE   NaN     NaN
# 15  PIPERACILLINE   NaN     NaN
# 16  PIPERACILLINE   NaN     NaN
# 17  PIPERACILLINE   NaN     NaN
# 18  PIPERACILLINE   NaN     NaN
#
#     Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit  \
# 0                                                                  1.4  NaN
# 1                                                                  1.4  NaN
# 2                                                                  1.4  NaN
# 3                                                                  1.4  NaN
# 4                                                                  1.4  NaN
# 5                                                                  1.4  NaN
# 6                                                                  1.4  NaN
# 7                                                                  1.4  NaN
# 8                                                                  1.4  NaN
# 9                                                                  1.4  NaN
# 10                                                                 1.4  NaN
# 11                                                                 1.4  NaN
# 12                                                                 1.4  NaN
# 13                                                                70.0  NaN
# 14                                                                70.0  NaN
# 15                                                                70.0  NaN
# 16                                                                70.0  NaN
# 17                                                                70.0  NaN
# 18                                                                70.0  NaN
#
#      chembl_id  molregno       pref_name  compound_name   compound_key  \
# 0   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 1   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 2   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 3   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 4   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 5   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 6   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 7   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 8   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 9   CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 10  CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 11  CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 12  CHEMBL1055    134333  CHLORTHALIDONE  CHLORTALIDONE  CHLORTALIDONE
# 13   CHEMBL702     33055    PIPERACILLIN  PIPERACILLINE  PIPERACILLINE
# 14   CHEMBL702     33055    PIPERACILLIN  PIPERACILLINE  PIPERACILLINE
# 15   CHEMBL702     33055    PIPERACILLIN  PIPERACILLINE  PIPERACILLINE
# 16   CHEMBL702     33055    PIPERACILLIN  PIPERACILLINE  PIPERACILLINE
# 17   CHEMBL702     33055    PIPERACILLIN  PIPERACILLINE  PIPERACILLINE
# 18   CHEMBL702     33055    PIPERACILLIN  PIPERACILLINE  PIPERACILLINE
#
#           synonyms       syn_type           standard_inchi_key  \
# 0    CHLORTALIDONE            ATC  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 1    CHLORTALIDONE            BAN  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 2    CHLORTALIDONE            BNF  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 3   CHLORTHALIDONE            FDA  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 4    CHLORTALIDONE            INN  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 5    CHLORTALIDONE            JAN  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 6   CHLORTHALIDONE          OTHER  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 7          G-33182  RESEARCH_CODE  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 8   CHLORTHALIDONE     TRADE_NAME  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 9         HYGROTON     TRADE_NAME  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 10       THALITONE     TRADE_NAME  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 11  CHLORTHALIDONE           USAN  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 12  CHLORTHALIDONE            USP  JIVPVXMEBJLZRO-UHFFFAOYSA-N
# 13    PIPERACILLIN            ATC  IVBHGBMCVLDMKU-GXNBUGAJSA-N
# 14    PIPERACILLIN            BAN  IVBHGBMCVLDMKU-GXNBUGAJSA-N
# 15    PIPERACILLIN            FDA  IVBHGBMCVLDMKU-GXNBUGAJSA-N
# 16    PIPERACILLIN            INN  IVBHGBMCVLDMKU-GXNBUGAJSA-N
# 17    PIPERACILLIN           USAN  IVBHGBMCVLDMKU-GXNBUGAJSA-N
# 18    PIPERACILLIN            USP  IVBHGBMCVLDMKU-GXNBUGAJSA-N
#
#                                                                           canonical_smiles  \
# 0                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 1                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 2                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 3                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 4                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 5                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 6                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 7                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 8                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 9                                               NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 10                                              NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 11                                              NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 12                                              NS(=O)(=O)c1cc(ccc1Cl)C2(O)NC(=O)c3ccccc23
# 13  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4ccccc4)C(=O)C1=O
# 14  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4ccccc4)C(=O)C1=O
# 15  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4ccccc4)C(=O)C1=O
# 16  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4ccccc4)C(=O)C1=O
# 17  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4ccccc4)C(=O)C1=O
# 18  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2=O)C(=O)O)c4ccccc4)C(=O)C1=O
#
#     mw_freebase
# 0        338.77
# 1        338.77
# 2        338.77
# 3        338.77
# 4        338.77
# 5        338.77
# 6        338.77
# 7        338.77
# 8        338.77
# 9        338.77
# 10       338.77
# 11       338.77
# 12       338.77
# 13       517.56
# 14       517.56
# 15       517.56
# 16       517.56
# 17       517.56
# 18       517.56

# %%
# Only two compounds in above, which have not been mapped yet (so don't need to regenerate unmapped for this round)
all_mappings.loc[all_mappings['pref_name'].isin(['CHLORTALIDONE', 'PIPERACILLINE']),:]
# Out:
# Empty DataFrame
# Columns: [Substance, pref_name, Blood-plasma concentration (mg/L) therapeutic (normal) upper limit, chembl_id, Salts, Synonym, Unit]
# Index: []

# %%
len(all_mappings)
# Out:
# 672

# %%
# Append these to all_mappings
all_mappings = pd.concat([all_mappings, round4_mappings[all_mappings.columns].drop_duplicates()], sort=False, ignore_index=True).drop_duplicates()

# %%
len(all_mappings)
# Out:
# 673

# %% [markdown]
# # Round 5
# Synonyms to synonyms

# %%
all_mappings.head()
# Out:
#             Substance        pref_name  \
# 0         ALENDRONATE  ALENDRONIC ACID
# 1        AZAPROPAZONE          APAZONE
# 2  DEXTROPROPOXYPHENE     PROPOXYPHENE
# 3          ETAMSYLATE      ETHAMSYLATE
# 4         INDOMETACIN     INDOMETHACIN
#
#    Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                               0.265
# 1                                                              90.000
# 2                                                               0.500
# 3                                                              20.000
# 4                                                               3.000
#
#        chembl_id Salts Synonym Unit
# 0      CHEMBL870   NaN     NaN  NaN
# 1  CHEMBL1565476   NaN     NaN  NaN
# 2  CHEMBL1213351   NaN     NaN  NaN
# 3  CHEMBL1514715   NaN     NaN  NaN
# 4        CHEMBL6   NaN     NaN  NaN

# %%
unmapped5 = plasma.loc[~plasma['Substance'].isin(all_mappings['Substance']),:]

# %%
len(unmapped5)
# Out:
# 200

# %%
# Synonyms to synonyms
syn_to_syn_mappings = pd.merge(unmapped5.loc[~unmapped5['Synonym'].isnull(),:], approved, left_on='Synonym',right_on='synonyms')[['Substance','pref_name','Synonym','chembl_id','canonical_smiles', 'Blood-plasma concentration (mg/L) therapeutic (normal) upper limit', 'Unit']].drop_duplicates()
syn_to_syn_mappings
# Out:
#                           Substance               pref_name  \
# 0                   4-AMINOPYRIDINE           DALFAMPRIDINE
# 108              3,4-DIAMINOPYRIDIN           AMIFAMPRIDINE
# 116                            GOLD  GOLD SODIUM THIOMALATE
# 128  THIOCYANATE FROM NITROPRUSSIDE    SODIUM NITROPRUSSIDE
#
#                    Synonym     chembl_id canonical_smiles  \
# 0               FAMPRIDINE  CHEMBL284348        Nc1ccncc1
# 108                    DAP  CHEMBL354077       Nc1ccncc1N
# 116  SODIUM AUROTHIOMALATE  CHEMBL306043              NaN
# 128   SODIUM NITROPRUSSIDE  CHEMBL136478              NaN
#
#      Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit
# 0                                                                 0.075  NaN
# 108                                                               0.100  NaN
# 116                                                               8.000  NaN
# 128                                                              30.000  NaN

# %%
len(all_mappings)
# Out:
# 673

# %%
all_mappings = pd.concat([all_mappings, syn_to_syn_mappings], sort=False, ignore_index=True)

# %%
len(all_mappings)
# Out:
# 677

# %%
# Check these manually?
unmapped5.loc[(~unmapped5['Synonym'].isnull())&(unmapped5['Synonym'].str.contains(',')),:]
# Out:
#                                Substance Salts  \
# 95                               BISMUTH   NaN
# 396           BETA-HEXACHLOROCYCLOHEXANE   NaN
# 405                    4-HYDROXYBUTYRATE   NaN
# 469                            LYSERGIDE   NaN
# 510   3,4-METHYLENEDIOXYETHYLAMPHETAMINE   NaN
# 511  3,4-METHYLENEDIOXYMETHYLAMPHETAMINE   NaN
#
#                               Synonym  \
# 95                     WISMUT, BISMUT
# 396            BETA-HCH, BETA-LINDANE
# 405               GHB, SODIUM OXYBATE
# 469  LYSERGIC ACID DIETHYL AMIDE, LSD
# 510                    MDEA, MDE; EVE
# 511          MDMA; ECSTASY, XTC; ADAM
#
#      Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit
# 95                                                               0.1000  NaN
# 396                                                              0.0001  NaN
# 405                                                            120.0000  NaN
# 469                                                              0.0050  NaN
# 510                                                              0.2000  NaN
# 511                                                              0.3500  NaN

# %%
all_mappings.head()
# Out:
#             Substance        pref_name  \
# 0         ALENDRONATE  ALENDRONIC ACID
# 1        AZAPROPAZONE          APAZONE
# 2  DEXTROPROPOXYPHENE     PROPOXYPHENE
# 3          ETAMSYLATE      ETHAMSYLATE
# 4         INDOMETACIN     INDOMETHACIN
#
#    Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                               0.265
# 1                                                              90.000
# 2                                                               0.500
# 3                                                              20.000
# 4                                                               3.000
#
#        chembl_id Salts Synonym Unit canonical_smiles
# 0      CHEMBL870   NaN     NaN  NaN              NaN
# 1  CHEMBL1565476   NaN     NaN  NaN              NaN
# 2  CHEMBL1213351   NaN     NaN  NaN              NaN
# 3  CHEMBL1514715   NaN     NaN  NaN              NaN
# 4        CHEMBL6   NaN     NaN  NaN              NaN

# %%
# hydroxybutyrate hasn't been mapped yet
all_mappings.loc[all_mappings['Substance']=='4-HYDROXYBUTYRATE',:]
# Out:
# Empty DataFrame
# Columns: [Substance, pref_name, Blood-plasma concentration (mg/L) therapeutic (normal) upper limit, chembl_id, Salts, Synonym, Unit, canonical_smiles]
# Index: []

# %%
oxybate = plasma.loc[plasma['Substance']=='4-HYDROXYBUTYRATE',:]

# %%
approved.loc[approved['pref_name']=='OXYBATE',['chembl_id', 'pref_name']].drop_duplicates()
# Out:
#          chembl_id pref_name
# 301588  CHEMBL1342   OXYBATE

# %%
oxybate['chembl_id'] = 'CHEMBL1342'
oxybate['pref_name'] = 'OXYBATE'
# Out:
# /scratch/ias41/envs/release/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /scratch/ias41/envs/release/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(all_mappings)
# Out:
# 677

# %%
all_mappings = pd.concat([all_mappings, oxybate], sort=False, ignore_index=True)

# %%
len(all_mappings)
# Out:
# 678

# %%
all_mappings.tail()
# Out:
#                           Substance               pref_name  \
# 673                 4-AMINOPYRIDINE           DALFAMPRIDINE
# 674              3,4-DIAMINOPYRIDIN           AMIFAMPRIDINE
# 675                            GOLD  GOLD SODIUM THIOMALATE
# 676  THIOCYANATE FROM NITROPRUSSIDE    SODIUM NITROPRUSSIDE
# 677               4-HYDROXYBUTYRATE                 OXYBATE
#
#      Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 673                                                               0.075
# 674                                                               0.100
# 675                                                               8.000
# 676                                                              30.000
# 677                                                             120.000
#
#         chembl_id Salts                Synonym Unit canonical_smiles
# 673  CHEMBL284348   NaN             FAMPRIDINE  NaN        Nc1ccncc1
# 674  CHEMBL354077   NaN                    DAP  NaN       Nc1ccncc1N
# 675  CHEMBL306043   NaN  SODIUM AUROTHIOMALATE  NaN              NaN
# 676  CHEMBL136478   NaN   SODIUM NITROPRUSSIDE  NaN              NaN
# 677    CHEMBL1342   NaN    GHB, SODIUM OXYBATE  NaN              NaN

# %%
# Checking that all 'substance' only have one mapping to chembl_id
test_counts = all_mappings.groupby('Substance').count()

# %%
test_counts.loc[test_counts['pref_name']>1,:]
# Out:
# Empty DataFrame
# Columns: [pref_name, Blood-plasma concentration (mg/L) therapeutic (normal) upper limit, chembl_id, Salts, Synonym, Unit, canonical_smiles]
# Index: []

# %%
len(all_mappings)
# Out:
# 678

# %% [markdown]
# # See currently unmapped

# %%
unmapped6 = plasma.loc[~plasma['Substance'].isin(all_mappings['Substance']),:]
len(unmapped6)
# Out:
# 195

# %%
unmapped6.head()
# Out:
#         Substance Salts Synonym  \
# 4    ACETALDEHYDE   NaN     NaN
# 7         ACETONE   NaN     NaN
# 8   ACETYLDIGOXIN   NaN     NaN
# 16       AJMALINE   NaN     NaN
# 19         ALDRIN   NaN     NaN
#
#     Blood-plasma concentration (mg/L) therapeutic (normal) upper limit Unit
# 4                                                              30.0000  NaN
# 7                                                              20.0000  NaN
# 8                                                               0.0008  NaN
# 16                                                              2.2100  NaN
# 19                                                              0.0015  NaN

# %%
unmapped6['short substance'] = unmapped6['Substance'].apply(lambda x: x.rstrip('E'))
# Out:
# /scratch/ias41/envs/release/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Attach mappings after considering trailing 'e'

# %%
# Noticed some names had an 'e' on the end that prevented synonym mapping
my_columns = [i for i in all_mappings.columns]
short_names = pd.merge(unmapped6, approved, left_on='short substance', right_on='pref_name')[my_columns].drop_duplicates()
short_names
# Out:
#       Substance   pref_name  \
# 0    ALFUZOSINE   ALFUZOSIN
# 60  DIBENZEPINE  DIBENZEPIN
# 72   LINEZOLIDE   LINEZOLID
#
#     Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                                 0.06
# 60                                                                0.50
# 72                                                                4.00
#
#         chembl_id Salts Synonym Unit  \
# 0       CHEMBL709   NaN     NaN  NaN
# 60  CHEMBL1442422   NaN     NaN  NaN
# 72      CHEMBL126   NaN     NaN  NaN
#
#                                   canonical_smiles
# 0      COc1cc2nc(nc(N)c2cc1OC)N(C)CCCNC(=O)C3CCCO3
# 60             CN(C)CCN1C(=O)c2ccccc2N(C)c3ccccc13
# 72  CC(=O)NC[C@H]1CN(C(=O)O1)c2ccc(N3CCOCC3)c(F)c2

# %%
len(all_mappings)
# Out:
# 678

# %%
all_mappings = pd.concat([all_mappings, short_names], sort = False, ignore_index=True)

# %%
len(all_mappings)
# Out:
# 681

# %%
all_mappings.tail()
# Out:
#                           Substance             pref_name  \
# 676  THIOCYANATE FROM NITROPRUSSIDE  SODIUM NITROPRUSSIDE
# 677               4-HYDROXYBUTYRATE               OXYBATE
# 678                      ALFUZOSINE             ALFUZOSIN
# 679                     DIBENZEPINE            DIBENZEPIN
# 680                      LINEZOLIDE             LINEZOLID
#
#      Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 676                                                               30.00
# 677                                                              120.00
# 678                                                                0.06
# 679                                                                0.50
# 680                                                                4.00
#
#          chembl_id Salts               Synonym Unit  \
# 676   CHEMBL136478   NaN  SODIUM NITROPRUSSIDE  NaN
# 677     CHEMBL1342   NaN   GHB, SODIUM OXYBATE  NaN
# 678      CHEMBL709   NaN                   NaN  NaN
# 679  CHEMBL1442422   NaN                   NaN  NaN
# 680      CHEMBL126   NaN                   NaN  NaN
#
#                                    canonical_smiles
# 676                                             NaN
# 677                                             NaN
# 678     COc1cc2nc(nc(N)c2cc1OC)N(C)CCCNC(=O)C3CCCO3
# 679             CN(C)CCN1C(=O)c2ccccc2N(C)c3ccccc13
# 680  CC(=O)NC[C@H]1CN(C(=O)O1)c2ccc(N3CCOCC3)c(F)c2

# %% [markdown]
# ## Attach the mw_freebase

# %%
all_mappings.head()
# Out:
#             Substance        pref_name  \
# 0         ALENDRONATE  ALENDRONIC ACID
# 1        AZAPROPAZONE          APAZONE
# 2  DEXTROPROPOXYPHENE     PROPOXYPHENE
# 3          ETAMSYLATE      ETHAMSYLATE
# 4         INDOMETACIN     INDOMETHACIN
#
#    Blood-plasma concentration (mg/L) therapeutic (normal) upper limit  \
# 0                                                               0.265
# 1                                                              90.000
# 2                                                               0.500
# 3                                                              20.000
# 4                                                               3.000
#
#        chembl_id Salts Synonym Unit canonical_smiles
# 0      CHEMBL870   NaN     NaN  NaN              NaN
# 1  CHEMBL1565476   NaN     NaN  NaN              NaN
# 2  CHEMBL1213351   NaN     NaN  NaN              NaN
# 3  CHEMBL1514715   NaN     NaN  NaN              NaN
# 4        CHEMBL6   NaN     NaN  NaN              NaN

# %%
with_freebase_initial = pd.merge(all_mappings, approved, on='chembl_id', suffixes=('', '_y'))

# %%
mylist = ['Substance'
 , 'pref_name'
 , 'Blood-plasma concentration (mg/L) therapeutic (normal) upper limit'
 , 'Unit'
 , 'chembl_id'
 , 'molregno'
 , 'mw_freebase']

# %%
with_freebase = with_freebase_initial.loc[:,mylist].drop_duplicates().reset_index(drop=True,inplace=False)
with_freebase['Unit'] = with_freebase['Unit'].fillna('mg/L')

# %%
with_freebase.columns
# Out:
# Index(['Substance', 'pref_name',
#        'Blood-plasma concentration (mg/L) therapeutic (normal) upper limit',
#        'Unit', 'chembl_id', 'molregno', 'mw_freebase'],
#       dtype='object')

# %%
with_freebase.columns = ['Original source Substance', 'pref_name',
       'Blood-plasma concentration, therapeutic (normal) upper limit',
       'Unit', 'chembl_id', 'molregno','mw_freebase']

# %%
all_info = with_freebase[['Original source Substance','pref_name', 'chembl_id', 'molregno','mw_freebase','Blood-plasma concentration, therapeutic (normal) upper limit', 'Unit']].sort_values(by='pref_name')

# %%
all_info.head()
# Out:
#     Original source Substance      pref_name      chembl_id  molregno  \
# 14                   ABACAVIR       ABACAVIR     CHEMBL1380    321707
# 15                ACAMPROSATE    ACAMPROSATE  CHEMBL1201293    675244
# 16                 ACEBUTOLOL     ACEBUTOLOL      CHEMBL642     27347
# 17              ACENOCOUMAROL  ACENOCOUMAROL   CHEMBL397420    394206
# 665               PARACETAMOL  ACETAMINOPHEN      CHEMBL112     16450
#
#      mw_freebase  \
# 14        286.34
# 15        181.21
# 16        336.43
# 17        353.33
# 665       151.16
#
#      Blood-plasma concentration, therapeutic (normal) upper limit  Unit
# 14                                                            3.9  mg/L
# 15                                                            0.7  mg/L
# 16                                                            2.0  mg/L
# 17                                                            0.5  mg/L
# 665                                                          25.0  mg/L

# %%
all_info.loc[all_info['Unit']!='mg/L',:]
# Out:
#     Original source Substance    pref_name   chembl_id  molregno  mw_freebase  \
# 174                CYSTEAMINE   CYSTEAMINE   CHEMBL602     21036        77.15
# 193                DIDANOSINE   DIDANOSINE  CHEMBL1460    390877       236.23
# 285               GEMCITABINE  GEMCITABINE   CHEMBL888     75901       263.20
#
#      Blood-plasma concentration, therapeutic (normal) upper limit    Unit
# 174                                                          20.0  umol/L
# 193                                                          30.0  umol/L
# 285                                                          20.0  umol/L

# %%
all_info.to_csv(basedir + '/results/interim/Schulz_ea_mapped_upper_plasma_concentrations.txt', sep='\t',index=None)
